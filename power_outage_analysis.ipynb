# %% [markdown]
# # Investigating Signs of High "Impact" Power Outages
#
# **Name(s)**: Turki Alrasheed
#
# **Website Link**: https://turkial2005.github.io/Power_Outage_Impact_Analysis/

# %%
import pandas as pd
import numpy as np

import plotly.express as px
pd.options.plotting.backend = 'plotly'
import plotly.io as pio
pio.renderers.default ="vscode"
import plotly.figure_factory as ff

# %% [markdown]
# ## Step 1: Introduction

# %% [markdown]
# Research Question: What are the signs indicating that a power outage has a big “impact” on people’s lives? “Impact” is a special metric created from a combination of number of customers lost and duration of power outage.

# %% [markdown]
# ## Step 2: Data Cleaning and Exploratory Data Analysis

# %%
df = pd.read_csv('power_outage.csv') # used google sheets to get the whole df as a csv
df = df.drop(0,axis=0) # first row is not an observation so need to remove it
# getting columns we are interested in
outage_df = df[['U.S._STATE','POSTAL.CODE', 'NERC.REGION','CAUSE.CATEGORY','CLIMATE.REGION',
            'ANOMALY.LEVEL','CLIMATE.CATEGORY','OUTAGE.DURATION','CUSTOMERS.AFFECTED', 
            'TOTAL.CUSTOMERS', 'TOTAL.PRICE', 'TOTAL.SALES', 'TOTAL.REALGSP','UTIL.REALGSP','UTIL.CONTRI',
            'PC.REALGSP.REL','POPULATION','POPDEN_URBAN', 'MONTH','YEAR','OUTAGE.START.DATE',
            'OUTAGE.START.TIME','OUTAGE.RESTORATION.DATE','OUTAGE.RESTORATION.TIME']]

outage_df
# Out:
#         U.S._STATE POSTAL.CODE NERC.REGION         CAUSE.CATEGORY  \
# 1        Minnesota          MN         MRO         severe weather
# 2        Minnesota          MN         MRO     intentional attack
# 3        Minnesota          MN         MRO         severe weather
# 4        Minnesota          MN         MRO         severe weather
# 5        Minnesota          MN         MRO         severe weather
# ...            ...         ...         ...                    ...
# 1530  North Dakota          ND         MRO          public appeal
# 1531  North Dakota          ND         MRO  fuel supply emergency
# 1532  South Dakota          SD         RFC              islanding
# 1533  South Dakota          SD         MRO              islanding
# 1534        Alaska          AK        ASCC      equipment failure
#
#           CLIMATE.REGION ANOMALY.LEVEL CLIMATE.CATEGORY OUTAGE.DURATION  \
# 1     East North Central          -0.3           normal            3060
# 2     East North Central          -0.1           normal               1
# 3     East North Central          -1.5             cold            3000
# 4     East North Central          -0.1           normal            2550
# 5     East North Central           1.2             warm            1740
# ...                  ...           ...              ...             ...
# 1530  West North Central          -0.9             cold             720
# 1531  West North Central           NaN              NaN             NaN
# 1532  West North Central           0.5             warm              59
# 1533  West North Central           0.5             warm             181
# 1534                 NaN           NaN              NaN             NaN
#
#       CUSTOMERS.AFFECTED  TOTAL.CUSTOMERS TOTAL.PRICE TOTAL.SALES  \
# 1                70000.0        2595696.0        9.28     6562520
# 2                    NaN        2640737.0        9.28     5284231
# 3                70000.0        2586905.0        8.15     5222116
# 4                68200.0        2606813.0        9.19     5787064
# 5               250000.0        2673531.0       10.43     5970339
# ...                  ...              ...         ...         ...
# 1530             34500.0         394394.0        7.56     1313678
# 1531                 NaN         366037.0         NaN         NaN
# 1532                 NaN         436229.0        7.67      924051
# 1533                 NaN         436229.0        7.67      924051
# 1534             14273.0         273530.0         NaN         NaN
#
#      TOTAL.REALGSP UTIL.REALGSP  UTIL.CONTRI PC.REALGSP.REL  POPULATION  \
# 1           274182         4802  1.751391412    1.077375699   5348119.0
# 2           291955         5226  1.790001884    1.089792426   5457125.0
# 3           267895         4571  1.706265514    1.066825978   5310903.0
# 4           277627         5364  1.932088738    1.071476036   5380443.0
# 5           292023         4873  1.668704177    1.092027125   5489594.0
# ...            ...          ...          ...            ...         ...
# 1530         39067          934  2.390764584     1.19808347    685326.0
# 1531         27868         1019  3.656523611    0.877404977    649422.0
# 1532         36504          606  1.660092045    0.968937446    807067.0
# 1533         36504          606  1.660092045    0.968937446    807067.0
# 1534         36046          724  2.008544637    1.282847246    627963.0
#
#      POPDEN_URBAN  MONTH    YEAR          OUTAGE.START.DATE OUTAGE.START.TIME  \
# 1            2279    7.0  2011.0       Friday, July 1, 2011        5:00:00 PM
# 2            2279    5.0  2014.0       Sunday, May 11, 2014        6:38:00 PM
# 3            2279   10.0  2010.0  Tuesday, October 26, 2010        8:00:00 PM
# 4            2279    6.0  2012.0     Tuesday, June 19, 2012        4:30:00 AM
# 5            2279    7.0  2015.0    Saturday, July 18, 2015        2:00:00 AM
# ...           ...    ...     ...                        ...               ...
# 1530       2192.2   12.0  2011.0  Tuesday, December 6, 2011        8:00:00 AM
# 1531       2192.2    NaN  2006.0                        NaN               NaN
# 1532       2038.3    8.0  2009.0  Saturday, August 29, 2009       10:54:00 PM
# 1533       2038.3    8.0  2009.0  Saturday, August 29, 2009       11:00:00 AM
# 1534       1802.6    NaN  2000.0                        NaN               NaN
#
#          OUTAGE.RESTORATION.DATE OUTAGE.RESTORATION.TIME
# 1           Sunday, July 3, 2011              8:00:00 PM
# 2           Sunday, May 11, 2014              6:39:00 PM
# 3     Thursday, October 28, 2010             10:00:00 PM
# 4       Wednesday, June 20, 2012             11:00:00 PM
# 5          Sunday, July 19, 2015              7:00:00 AM
# ...                          ...                     ...
# 1530   Tuesday, December 6, 2011              8:00:00 PM
# 1531                         NaN                     NaN
# 1532   Saturday, August 29, 2009             11:53:00 PM
# 1533   Saturday, August 29, 2009              2:01:00 PM
# 1534                         NaN                     NaN
#
# [1534 rows x 24 columns]

# %%
 # combinbing date and time for outage start and restoration
outage_df['OUTAGE.START'] = pd.to_datetime(outage_df['OUTAGE.START.DATE'] + ' ' + outage_df['OUTAGE.START.TIME'],format="%A, %B %d, %Y %I:%M:%S %p")
outage_df['OUTAGE.RESTORATION'] =pd.to_datetime(outage_df['OUTAGE.RESTORATION.DATE'] + ' ' + outage_df['OUTAGE.RESTORATION.TIME'],format="%A, %B %d, %Y %I:%M:%S %p")

outage_df = outage_df.drop(columns =["OUTAGE.START.DATE",
"OUTAGE.START.TIME",
"OUTAGE.RESTORATION.DATE",
"OUTAGE.RESTORATION.TIME"],axis=1 )

# %%
for i,j in outage_df.dtypes.items():
    print(i,j)
# Out:
# U.S._STATE object
# POSTAL.CODE object
# NERC.REGION object
# CAUSE.CATEGORY object
# CLIMATE.REGION object
# ANOMALY.LEVEL object
# CLIMATE.CATEGORY object
# OUTAGE.DURATION object
# CUSTOMERS.AFFECTED float64
# TOTAL.CUSTOMERS float64
# TOTAL.PRICE object
# TOTAL.SALES object
# TOTAL.REALGSP object
# UTIL.REALGSP object
# UTIL.CONTRI object
# PC.REALGSP.REL object
# POPULATION float64
# POPDEN_URBAN object
# MONTH float64
# YEAR float64
# OUTAGE.START datetime64[ns]
# OUTAGE.RESTORATION datetime64[ns]

# %%
# need to make numbers into floats
outage_df[['ANOMALY.LEVEL','OUTAGE.DURATION','TOTAL.PRICE','TOTAL.SALES','TOTAL.REALGSP', 'UTIL.REALGSP','POPDEN_URBAN','PC.REALGSP.REL','UTIL.CONTRI']] = (
    outage_df[['ANOMALY.LEVEL','OUTAGE.DURATION','TOTAL.PRICE','TOTAL.SALES','TOTAL.REALGSP','UTIL.REALGSP','POPDEN_URBAN','PC.REALGSP.REL','UTIL.CONTRI']].astype(float))

# %%
for i,j in outage_df.dtypes.items():
    print(i,j)
# Out:
# U.S._STATE object
# POSTAL.CODE object
# NERC.REGION object
# CAUSE.CATEGORY object
# CLIMATE.REGION object
# ANOMALY.LEVEL float64
# CLIMATE.CATEGORY object
# OUTAGE.DURATION float64
# CUSTOMERS.AFFECTED float64
# TOTAL.CUSTOMERS float64
# TOTAL.PRICE float64
# TOTAL.SALES float64
# TOTAL.REALGSP float64
# UTIL.REALGSP float64
# UTIL.CONTRI float64
# PC.REALGSP.REL float64
# POPULATION float64
# POPDEN_URBAN float64
# MONTH float64
# YEAR float64
# OUTAGE.START datetime64[ns]
# OUTAGE.RESTORATION datetime64[ns]

# %%
print((outage_df['MONTH'] == 0).sum())
print((outage_df['YEAR'] == 0).sum())
print((outage_df["TOTAL.CUSTOMERS"] == 0).sum() )
print((outage_df['TOTAL.SALES'] == 0).sum())
print((outage_df['TOTAL.SALES'] == 0).sum())
print((outage_df['TOTAL.PRICE'] == 0).sum())
print((outage_df['PC.REALGSP.REL'] == 0).sum())
print((outage_df['UTIL.REALGSP'] == 0).sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
(outage_df['OUTAGE.DURATION'] == 0).sum() # gave us 78
outage_df['OUTAGE.DURATION'] = outage_df['OUTAGE.DURATION'].replace({0:np.nan})

# %%
(outage_df["CUSTOMERS.AFFECTED"] == 0).sum() # gave us 212

outage_df["CUSTOMERS.AFFECTED"] = outage_df["CUSTOMERS.AFFECTED"].replace({0:np.nan})

# %%
for i in outage_df.columns:
    print(f"{i}: {outage_df[i].isna().sum()}")
# Out:
# U.S._STATE: 0
# POSTAL.CODE: 0
# NERC.REGION: 0
# CAUSE.CATEGORY: 0
# CLIMATE.REGION: 6
# ANOMALY.LEVEL: 9
# CLIMATE.CATEGORY: 9
# OUTAGE.DURATION: 136
# CUSTOMERS.AFFECTED: 655
# TOTAL.CUSTOMERS: 0
# TOTAL.PRICE: 22
# TOTAL.SALES: 22
# TOTAL.REALGSP: 0
# UTIL.REALGSP: 0
# UTIL.CONTRI: 0
# PC.REALGSP.REL: 0
# POPULATION: 0
# POPDEN_URBAN: 0
# MONTH: 9
# YEAR: 0
# OUTAGE.START: 9
# OUTAGE.RESTORATION: 58

# %% [markdown]
# ### Identifying Missingness Mechanisms For Customers Affected and Imputation

# %%
def tvd_perm_test(df, column,column_missing):
    np.random.seed(22)
    n_repetitions = 1000
    shuffled = df.copy()
    col_missing = column_missing
    col = column
    shuffled[f'{col_missing}_IS_MISSING'] = shuffled[col_missing].isna()
    
    tvds = []
    for _ in range(n_repetitions):
        
    
        shuffled[col] = np.random.permutation(shuffled[col])
        
      
        pivoted = (
            shuffled
            .pivot_table(index=col, columns=f'{col_missing}_IS_MISSING', aggfunc='size')
        )
        
        pivoted = pivoted / pivoted.sum()
        
        tvd = pivoted.diff(axis=1).iloc[:, -1].abs().sum() / 2
        tvds.append(tvd)
    return tvds
def pivot_table(df, col, col_missing):
    df_copy = df.copy()
    df_copy[f'{col_missing}_IS_MISSING'] = df_copy[col_missing].isna()
    pv = df_copy.pivot_table(index=col, columns=f'{col_missing}_IS_MISSING', aggfunc='size',fill_value=0)
    pv = pv/pv.sum()
    return pv

# %%
obs_pivot_y = pivot_table(outage_df, 'CLIMATE.CATEGORY', 'CUSTOMERS.AFFECTED')
obs_stat_y = obs_pivot_y.diff(axis=1).iloc[:, -1].abs().sum() / 2
obs_stat_y
# Out:
# 0.02647273697964231

# %%
tvds_y = tvd_perm_test(outage_df,'CLIMATE.CATEGORY','CUSTOMERS.AFFECTED')

# %%
p_value = (tvds_y >= obs_stat_y).mean()
p_value
# Out:
# 0.494

# %%
fig = px.histogram(pd.DataFrame({'tvds':tvds_y}),histnorm='probability', 
                   title='Empirical Distribution of the TVD')
fig.add_vline(x=obs_stat_y, line_color='red', line_width=2, opacity=1)
fig.add_annotation(text=f'<span style="color:red">Observed TVD = {round(obs_stat_y, 2)}</span>',
                   x=0.85 * obs_stat_y, showarrow=False, y=0.09)
fig.update_layout(yaxis_range=[0, 0.1])
fig.update_layout(xaxis_range=[0, 0.1])
fig.update_layout(showlegend=False)
fig.update_layout(
    xaxis_title="Generated TVDs"  
)

# %%
obs_pivot = pivot_table(outage_df, 'U.S._STATE', 'CUSTOMERS.AFFECTED')
observed_statistic = obs_pivot.diff(axis=1).iloc[:, -1].abs().sum() / 2
observed_statistic
# Out:
# 0.38676497407706534

# %%
obs_pivot.plot(kind='barh', title='Gender by Missingness of Child Height (MAR Example)', barmode='group')

# %%
def tvd_perm_test(df, column,column_missing):
    np.random.seed(22)
    n_repetitions = 1000
    shuffled = df.copy()
    col_missing = column_missing
    col = column
    shuffled[f'{col_missing}_IS_MISSING'] = shuffled[col_missing].isna()
    
    tvds = []
    for _ in range(n_repetitions):
        
    
        shuffled[col] = np.random.permutation(shuffled[col])
        
      
        pivoted = (
            shuffled
            .pivot_table(index=col, columns=f'{col_missing}_IS_MISSING', aggfunc='size')
        )
        
        pivoted = pivoted / pivoted.sum()
        
        tvd = pivoted.diff(axis=1).iloc[:, -1].abs().sum() / 2
        tvds.append(tvd)
    return tvds

# %%
tvds = tvd_perm_test(outage_df, 'U.S._STATE','CUSTOMERS.AFFECTED')

# %%
p_value = (tvds >= observed_statistic).mean()
p_value
# Out:
# 0.0

# %%
fig = px.histogram(pd.DataFrame({'tvds':tvds}),histnorm='probability', 
                   title='Empirical Distribution of the TVD')
fig.add_vline(x=observed_statistic, line_color='red', line_width=2, opacity=1)
fig.add_annotation(text=f'<span style="color:red">Observed TVD = {round(observed_statistic, 2)}</span>',
                   x=0.95 * observed_statistic, showarrow=False, y=0.12)
fig.update_layout(yaxis_range=[0, 0.13])
fig.update_layout(xaxis_range=[0, 0.4])
fig.update_layout(showlegend=False)
fig.update_layout(
    xaxis_title="Generated TVDs"  
)

# %%
pv_cause = pivot_table(outage_df, 'CAUSE.CATEGORY', 'CUSTOMERS.AFFECTED')
obs_stat_cause = pv_cause.diff(axis=1).iloc[:, -1].abs().sum() / 2
obs_stat_cause
# Out:
# 0.7557790341210083

# %%
pv_cause.plot(kind='barh', title='Gender by Missingness of Child Height (MAR Example)', barmode='group')

# %%
tvds2 = tvd_perm_test(outage_df, 'CAUSE.CATEGORY','CUSTOMERS.AFFECTED')

# %%
p_value2 =(tvds >= obs_stat_cause).mean()
p_value2
# Out:
# 0.0

# %%
fig = px.histogram(pd.DataFrame({'tvds':tvds2}),histnorm='probability',nbins = 20,
                   title='Empirical Distribution of the TVD')
fig.add_vline(x=obs_stat_cause, line_color='red', line_width=2, opacity=1)
fig.add_annotation(text=f'<span style="color:red">Observed TVD = {round(obs_stat_cause, 2)}</span>',
                   x=0.95 * obs_stat_cause, showarrow=False, y=0.14)
fig.update_layout(yaxis_range=[0, 0.15])
fig.update_layout(xaxis_range=[0, 0.8])
fig.update_layout(showlegend=False)
fig.update_layout(
    xaxis_title="Generated TVDs"  
)

# %%
def prob_impute(s):
    s = s.copy()
    
    num_null = s.isna().sum()
    
    fill_values = np.random.choice(s.dropna(), num_null)
    
    s[s.isna()] = fill_values
    return s
def one_impute(df, column, seed,groupby_col=None):
    np.random.seed(seed)
    df_copy = df.copy()

    if groupby_col:
        df_copy[column] = df_copy.groupby(groupby_col)[column].transform(lambda s: prob_impute(s))
    else:
        df_copy[column] =  prob_impute(df_copy[column])
    
    return df_copy[column]

# %%
imputed_cus_aff = one_impute(outage_df, 'CUSTOMERS.AFFECTED',23,'CAUSE.CATEGORY')
imputed_cus_df = pd.DataFrame({"CUSTOMERS.AFFECTED":imputed_cus_aff})
imputed_cus_df
# Out:
#       CUSTOMERS.AFFECTED
# 1                70000.0
# 2                  215.0
# 3                70000.0
# 4                68200.0
# 5               250000.0
# ...                  ...
# 1530             34500.0
# 1531                 1.0
# 1532                 4.0
# 1533             15000.0
# 1534             14273.0
#
# [1534 rows x 1 columns]

# %%
def multiple_imputation(df, column, seed,mult,num_imputations=5, groupby_col=None):
    imputed_dfs = [one_impute(df, column,seed + mult*i, groupby_col) for i in range(num_imputations)]
    return np.mean(imputed_dfs, axis=0) 
mimputed_cus_aff = multiple_imputation(outage_df, 'CUSTOMERS.AFFECTED',23,2,50,'CAUSE.CATEGORY')
mimputed_cus_df = pd.DataFrame({"CUSTOMERS.AFFECTED":mimputed_cus_aff })
mimputed_cus_df
# Out:
#       CUSTOMERS.AFFECTED
# 0               70000.00
# 1               13896.36
# 2               70000.00
# 3               68200.00
# 4              250000.00
# ...                  ...
# 1529            34500.00
# 1530                1.00
# 1531             5597.56
# 1532             8297.94
# 1533            14273.00
#
# [1534 rows x 1 columns]

# %%
def multiple_kdes(df_map, col, title=""):
    values = [df_map[key][col].dropna() for key in df_map]
    labels = list(df_map.keys())
    fig = ff.create_distplot(
        hist_data=values,
        group_labels=labels,
        show_rug=False,
        show_hist=False,
        colors=px.colors.qualitative.Dark2[: len(df_map)],
    )
 
    return fig.update_layout(title=title).update_xaxes(title=col)



multiple_kdes({'Original': outage_df, 'MAR, Filled, single_prop': imputed_cus_df, 'MAR, Filled, mult_prop':mimputed_cus_df},'CUSTOMERS.AFFECTED')

# %%
outage_df['CUSTOMERS.AFFECTED.FILLED'] = mimputed_cus_aff

# %% [markdown]
# ### Identifying Missingness Mechanisms For Outage Duration and Imputation

# %%
obs_pivot_c = pivot_table(outage_df, 'CAUSE.CATEGORY', 'OUTAGE.DURATION')
obs_stat_c = obs_pivot_c.diff(axis=1).iloc[:, -1].abs().sum() / 2

dur_tvds_c = tvd_perm_test(outage_df, 'CAUSE.CATEGORY','OUTAGE.DURATION')


(dur_tvds_c >= obs_stat_c).mean()
# Out:
# 0.0

# %%
dur_tvds_s = tvd_perm_test(outage_df, 'U.S._STATE','OUTAGE.DURATION')

obs_pivot_s = pivot_table(outage_df, 'U.S._STATE', 'OUTAGE.DURATION')
obs_stat_s = obs_pivot_s.diff(axis=1).iloc[:, -1].abs().sum() / 2
obs_stat_s

(dur_tvds_s >= obs_stat_s).mean()
# Out:
# 0.0

# %%
imputed_out = one_impute(outage_df, 'OUTAGE.DURATION',30,'CAUSE.CATEGORY')
imputed_out_df = pd.DataFrame({'OUTAGE.DURATION':imputed_out })
imputed_out_df
# Out:
#       OUTAGE.DURATION
# 1              3060.0
# 2                 1.0
# 3              3000.0
# 4              2550.0
# 5              1740.0
# ...               ...
# 1530            720.0
# 1531            660.0
# 1532             59.0
# 1533            181.0
# 1534           1204.0
#
# [1534 rows x 1 columns]

# %%
mimputed_out = multiple_imputation(outage_df, 'OUTAGE.DURATION',30,3,50,'CAUSE.CATEGORY')
mimputed_out_df = pd.DataFrame({'OUTAGE.DURATION':mimputed_out })
mimputed_out_df
# Out:
#       OUTAGE.DURATION
# 0             3060.00
# 1                1.00
# 2             3000.00
# 3             2550.00
# 4             1740.00
# ...               ...
# 1529           720.00
# 1530         14907.46
# 1531            59.00
# 1532           181.00
# 1533          2006.40
#
# [1534 rows x 1 columns]

# %%
def multiple_kdes(df_map, col, title=""):
    values = [df_map[key][col].dropna() for key in df_map]
    labels = list(df_map.keys())
    fig = ff.create_distplot(
        hist_data=values,
        group_labels=labels,
        show_rug=False,
        show_hist=False,
        colors=px.colors.qualitative.Dark2[: len(df_map)],
    )
    min_value = min(df[col].min() for df in df_map.values())
    max_value = max(df[col].max() for df in df_map.values())
    return fig.update_layout(title=title).update_xaxes(title=col, range=[min_value, max_value])

multiple_kdes({'Original': outage_df, 'MAR, Filled, Single Imputation': imputed_out_df, 'MAR, Filled, Multiple Imputation':mimputed_out_df},'OUTAGE.DURATION')

# %%
outage_df["OUTAGE.DURATION.FILLED"] = mimputed_out

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

impact_features = ['CUSTOMERS.AFFECTED.FILLED', 'OUTAGE.DURATION.FILLED']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(outage_df[impact_features])
X_scaled
# Out:
# array([[-0.21437911,  0.05384061],
#        [-0.44098305, -0.46226863],
#        [-0.21437911,  0.04371751],
#        ...,
#        [-0.4745021 , -0.45248297],
#        [-0.4635952 , -0.43189934],
#        [-0.43946179, -0.12392098]])

# %%
pca = PCA(n_components=1)
impact_score = pca.fit_transform(X_scaled)

outage_df['IMPACT_SCORE'] = impact_score
outage_df['IMPACT_SCORE']
# Out:
# 1      -0.113518
# 2      -0.638695
# 3      -0.120676
# 4      -0.179503
# 5       0.243088
#           ...
# 1530   -0.494073
# 1531    1.099987
# 1532   -0.655477
# 1533   -0.633210
# 1534   -0.398372
# Name: IMPACT_SCORE, Length: 1534, dtype: float64

# %%
outage_df=outage_df.drop(['OUTAGE.DURATION.FILLED','CUSTOMERS.AFFECTED.FILLED','OUTAGE.DURATION','CUSTOMERS.AFFECTED'],axis=1)

# %%
outage_df
# Out:
#         U.S._STATE POSTAL.CODE NERC.REGION         CAUSE.CATEGORY  \
# 1        Minnesota          MN         MRO         severe weather
# 2        Minnesota          MN         MRO     intentional attack
# 3        Minnesota          MN         MRO         severe weather
# 4        Minnesota          MN         MRO         severe weather
# 5        Minnesota          MN         MRO         severe weather
# ...            ...         ...         ...                    ...
# 1530  North Dakota          ND         MRO          public appeal
# 1531  North Dakota          ND         MRO  fuel supply emergency
# 1532  South Dakota          SD         RFC              islanding
# 1533  South Dakota          SD         MRO              islanding
# 1534        Alaska          AK        ASCC      equipment failure
#
#           CLIMATE.REGION  ANOMALY.LEVEL CLIMATE.CATEGORY  TOTAL.CUSTOMERS  \
# 1     East North Central           -0.3           normal        2595696.0
# 2     East North Central           -0.1           normal        2640737.0
# 3     East North Central           -1.5             cold        2586905.0
# 4     East North Central           -0.1           normal        2606813.0
# 5     East North Central            1.2             warm        2673531.0
# ...                  ...            ...              ...              ...
# 1530  West North Central           -0.9             cold         394394.0
# 1531  West North Central            NaN              NaN         366037.0
# 1532  West North Central            0.5             warm         436229.0
# 1533  West North Central            0.5             warm         436229.0
# 1534                 NaN            NaN              NaN         273530.0
#
#       TOTAL.PRICE  TOTAL.SALES  TOTAL.REALGSP  UTIL.REALGSP  UTIL.CONTRI  \
# 1            9.28    6562520.0       274182.0        4802.0     1.751391
# 2            9.28    5284231.0       291955.0        5226.0     1.790002
# 3            8.15    5222116.0       267895.0        4571.0     1.706266
# 4            9.19    5787064.0       277627.0        5364.0     1.932089
# 5           10.43    5970339.0       292023.0        4873.0     1.668704
# ...           ...          ...            ...           ...          ...
# 1530         7.56    1313678.0        39067.0         934.0     2.390765
# 1531          NaN          NaN        27868.0        1019.0     3.656524
# 1532         7.67     924051.0        36504.0         606.0     1.660092
# 1533         7.67     924051.0        36504.0         606.0     1.660092
# 1534          NaN          NaN        36046.0         724.0     2.008545
#
#       PC.REALGSP.REL  POPULATION  POPDEN_URBAN  MONTH    YEAR  \
# 1           1.077376   5348119.0        2279.0    7.0  2011.0
# 2           1.089792   5457125.0        2279.0    5.0  2014.0
# 3           1.066826   5310903.0        2279.0   10.0  2010.0
# 4           1.071476   5380443.0        2279.0    6.0  2012.0
# 5           1.092027   5489594.0        2279.0    7.0  2015.0
# ...              ...         ...           ...    ...     ...
# 1530        1.198083    685326.0        2192.2   12.0  2011.0
# 1531        0.877405    649422.0        2192.2    NaN  2006.0
# 1532        0.968937    807067.0        2038.3    8.0  2009.0
# 1533        0.968937    807067.0        2038.3    8.0  2009.0
# 1534        1.282847    627963.0        1802.6    NaN  2000.0
#
#             OUTAGE.START  OUTAGE.RESTORATION  IMPACT_SCORE
# 1    2011-07-01 17:00:00 2011-07-03 20:00:00     -0.113518
# 2    2014-05-11 18:38:00 2014-05-11 18:39:00     -0.638695
# 3    2010-10-26 20:00:00 2010-10-28 22:00:00     -0.120676
# 4    2012-06-19 04:30:00 2012-06-20 23:00:00     -0.179503
# 5    2015-07-18 02:00:00 2015-07-19 07:00:00      0.243088
# ...                  ...                 ...           ...
# 1530 2011-12-06 08:00:00 2011-12-06 20:00:00     -0.494073
# 1531                 NaT                 NaT      1.099987
# 1532 2009-08-29 22:54:00 2009-08-29 23:53:00     -0.655477
# 1533 2009-08-29 11:00:00 2009-08-29 14:01:00     -0.633210
# 1534                 NaT                 NaT     -0.398372
#
# [1534 rows x 21 columns]

# %%
print(outage_df.head().to_markdown(index=False))
# Out:
# | U.S._STATE   | POSTAL.CODE   | NERC.REGION   | CAUSE.CATEGORY     | CLIMATE.REGION     |   ANOMALY.LEVEL | CLIMATE.CATEGORY   |   TOTAL.CUSTOMERS |   TOTAL.PRICE |   TOTAL.SALES |   TOTAL.REALGSP |   UTIL.REALGSP |   UTIL.CONTRI |   PC.REALGSP.REL |   POPULATION |   POPDEN_URBAN |   MONTH |   YEAR | OUTAGE.START        | OUTAGE.RESTORATION   |   IMPACT_SCORE |
# |:-------------|:--------------|:--------------|:-------------------|:-------------------|----------------:|:-------------------|------------------:|--------------:|--------------:|----------------:|---------------:|--------------:|-----------------:|-------------:|---------------:|--------:|-------:|:--------------------|:---------------------|---------------:|
# | Minnesota    | MN            | MRO           | severe weather     | East North Central |            -0.3 | normal             |       2.5957e+06  |          9.28 |   6.56252e+06 |          274182 |           4802 |       1.75139 |          1.07738 |  5.34812e+06 |           2279 |       7 |   2011 | 2011-07-01 17:00:00 | 2011-07-03 20:00:00  |      -0.113518 |
# | Minnesota    | MN            | MRO           | intentional attack | East North Central |            -0.1 | normal             |       2.64074e+06 |          9.28 |   5.28423e+06 |          291955 |           5226 |       1.79    |          1.08979 |  5.45712e+06 |           2279 |       5 |   2014 | 2014-05-11 18:38:00 | 2014-05-11 18:39:00  |      -0.638695 |
# | Minnesota    | MN            | MRO           | severe weather     | East North Central |            -1.5 | cold               |       2.5869e+06  |          8.15 |   5.22212e+06 |          267895 |           4571 |       1.70627 |          1.06683 |  5.3109e+06  |           2279 |      10 |   2010 | 2010-10-26 20:00:00 | 2010-10-28 22:00:00  |      -0.120676 |
# | Minnesota    | MN            | MRO           | severe weather     | East North Central |            -0.1 | normal             |       2.60681e+06 |          9.19 |   5.78706e+06 |          277627 |           5364 |       1.93209 |          1.07148 |  5.38044e+06 |           2279 |       6 |   2012 | 2012-06-19 04:30:00 | 2012-06-20 23:00:00  |      -0.179503 |
# | Minnesota    | MN            | MRO           | severe weather     | East North Central |             1.2 | warm               |       2.67353e+06 |         10.43 |   5.97034e+06 |          292023 |           4873 |       1.6687  |          1.09203 |  5.48959e+06 |           2279 |       7 |   2015 | 2015-07-18 02:00:00 | 2015-07-19 07:00:00  |       0.243088 |

# %% [markdown]
# ### Univariate Analysis

# %%
fig = px.histogram(outage_df,x='IMPACT_SCORE',histnorm='probability',marginal='box',
                   title='Distribution of Impact Scores')
fig.update_layout(
    width=800,  
    height=600    
)
fig.show()

# %%
outage_df['IMPACT_SCORE'].mean()
# Out:
# -4.631960467797263e-18

# %%
cause_counts = (outage_df.groupby('CAUSE.CATEGORY').size().reset_index()
                .rename(columns = {'CAUSE.CATEGORY': "Cause Category", 0:"Number of Outages"})
                .sort_values("Number of Outages",ascending=False))

dist_causes = px.bar(cause_counts, x='Cause Category', y="Number of Outages", title="Number of Power Outages for Each Major Cause")
dist_causes.update_layout(
    width=800,  
    height=600    
)
dist_causes.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
fig = px.box(outage_df, x="CAUSE.CATEGORY", y="IMPACT_SCORE",
             title="Box Plots of Impact Scores by Cause Category",
             labels={"CAUSE.CATEGORY": "Cause Category", "IMPACT_SCORE": "Impact Score"},
             color="CAUSE.CATEGORY")  # Colors by category
fig.update_layout(
    width=800,  
    height=600   
)
fig.show()

# %%
fig = px.box(outage_df, x="CLIMATE.REGION", y="IMPACT_SCORE",
             title="Box Plots of Impact Scores by Climate Region",
             labels={"CLIMATE.REGION": "Climate Region", "IMPACT_SCORE": "Impact Score"},
             color="CLIMATE.REGION")  # Colors by category

fig.show()

# %%
fig = px.box(outage_df, x="NERC.REGION", y="IMPACT_SCORE",
             title="Box Plots of Impact Scores by NERC Region",
             labels={"NERC.REGION": "NERC Region", "IMPACT_SCORE": "Impact Score"},
             color="NERC.REGION")  # Colors by category

fig.show()

# %%
fig = px.box(outage_df, x="CLIMATE.CATEGORY", y="IMPACT_SCORE",
             title="Box Plots of Impact Scores by Climate Category",
             labels={"CLIMATE.CATEGORY": "Climate Category", "IMPACT_SCORE": "Impact Score"},
             color="CLIMATE.CATEGORY")  # Colors by category

fig.show()

# %%
fig = px.scatter(outage_df, x="TOTAL.SALES", y="IMPACT_SCORE",
                 title="Impact Score vs. Total Sales",
                 labels={"TOTAL.SALES": "Total Sales", "IMPACT_SCORE": "Impact Score"})  # Adds an optional trendline

fig.show()

# %%
fig = px.scatter(outage_df, x="POPDEN_URBAN", y="IMPACT_SCORE",
                 title="Impact Score vs. Urban Population Density",
                 labels={"POPDEN_URBAN": "Urban Population Density", "IMPACT_SCORE": "Impact Score"})  # Adds an optional trendline

fig.show()

# %%
impact_avg = outage_df.groupby("YEAR")["IMPACT_SCORE"].mean().reset_index()

fig = px.line(impact_avg, x="YEAR", y="IMPACT_SCORE",
              title="Trend of Impact Score Over the Years",
              labels={"YEAR": "Year", "IMPACT_SCORE": "Average Impact Score"},
              markers=True)
fig.update_layout(
    width=800,  
    height=600   
)

#fig.show()

# %%
impact_avg = outage_df.groupby("POSTAL.CODE").agg(
    IMPACT_SCORE=('IMPACT_SCORE', 'mean'),
    State_Name=('U.S._STATE', 'first')  
).reset_index()

fig = px.choropleth(impact_avg,
                     locations="POSTAL.CODE", 
                     locationmode="USA-states",
                     color="IMPACT_SCORE",  
                     color_continuous_scale="Reds",  
                     title="Average Impact Score by U.S. State",
                     labels={"IMPACT_SCORE": "Average Impact Score"},
                     scope="usa",
                     hover_name="State_Name"  )  
fig.update_layout(
    width=800,  
    height=600   
)


fig.show()
impact_avg
# Out:
#    POSTAL.CODE  IMPACT_SCORE            State_Name
# 0           AK     -0.398372                Alaska
# 1           AL     -0.262630               Alabama
# 2           AR     -0.318978              Arkansas
# 3           AZ     -0.040913               Arizona
# 4           CA      0.046270            California
# 5           CO     -0.208507              Colorado
# 6           CT     -0.338605           Connecticut
# 7           DC      0.395542  District of Columbia
# 8           DE     -0.548107              Delaware
# 9           FL      0.690109               Florida
# 10          GA     -0.189707               Georgia
# 11          HI     -0.157133                Hawaii
# 12          IA      0.063764                  Iowa
# 13          ID     -0.494814                 Idaho
# 14          IL      0.101135              Illinois
# 15          IN     -0.065331               Indiana
# 16          KS      0.097168                Kansas
# 17          KY      0.289206              Kentucky
# 18          LA      0.110756             Louisiana
# 19          MA     -0.351625         Massachusetts
# 20          MD     -0.079076              Maryland
# 21          ME     -0.386279                 Maine
# 22          MI      0.381450              Michigan
# 23          MN     -0.010193             Minnesota
# 24          MO     -0.140996              Missouri
# 25          MS     -0.622374           Mississippi
# 26          MT     -0.644611               Montana
# 27          NC     -0.209808        North Carolina
# 28          ND      0.302957          North Dakota
# 29          NE     -0.187460              Nebraska
# 30          NH     -0.557173         New Hampshire
# 31          NJ      0.271468            New Jersey
# 32          NM     -0.440708            New Mexico
# 33          NV     -0.528472                Nevada
# 34          NY      0.441584              New York
# 35          OH      0.038919                  Ohio
# 36          OK      0.086187              Oklahoma
# 37          OR     -0.486151                Oregon
# 38          PA      0.246686          Pennsylvania
# 39          SC      0.414978        South Carolina
# 40          SD     -0.644344          South Dakota
# 41          TN     -0.270502             Tennessee
# 42          TX      0.190911                 Texas
# 43          UT     -0.568645                  Utah
# 44          VA     -0.106829              Virginia
# 45          VT     -0.625497               Vermont
# 46          WA     -0.305402            Washington
# 47          WI      0.415042             Wisconsin
# 48          WV      0.559489         West Virginia
# 49          WY     -0.575741               Wyoming

# %%
impact_avg.sort_values('IMPACT_SCORE')
# Out:
#    POSTAL.CODE  IMPACT_SCORE            State_Name
# 26          MT     -0.644611               Montana
# 40          SD     -0.644344          South Dakota
# 45          VT     -0.625497               Vermont
# 25          MS     -0.622374           Mississippi
# 49          WY     -0.575741               Wyoming
# 43          UT     -0.568645                  Utah
# 30          NH     -0.557173         New Hampshire
# 8           DE     -0.548107              Delaware
# 33          NV     -0.528472                Nevada
# 13          ID     -0.494814                 Idaho
# 37          OR     -0.486151                Oregon
# 32          NM     -0.440708            New Mexico
# 0           AK     -0.398372                Alaska
# 21          ME     -0.386279                 Maine
# 19          MA     -0.351625         Massachusetts
# 6           CT     -0.338605           Connecticut
# 2           AR     -0.318978              Arkansas
# 46          WA     -0.305402            Washington
# 41          TN     -0.270502             Tennessee
# 1           AL     -0.262630               Alabama
# 27          NC     -0.209808        North Carolina
# 5           CO     -0.208507              Colorado
# 10          GA     -0.189707               Georgia
# 29          NE     -0.187460              Nebraska
# 11          HI     -0.157133                Hawaii
# 24          MO     -0.140996              Missouri
# 44          VA     -0.106829              Virginia
# 20          MD     -0.079076              Maryland
# 15          IN     -0.065331               Indiana
# 3           AZ     -0.040913               Arizona
# 23          MN     -0.010193             Minnesota
# 35          OH      0.038919                  Ohio
# 4           CA      0.046270            California
# 12          IA      0.063764                  Iowa
# 36          OK      0.086187              Oklahoma
# 16          KS      0.097168                Kansas
# 14          IL      0.101135              Illinois
# 18          LA      0.110756             Louisiana
# 42          TX      0.190911                 Texas
# 38          PA      0.246686          Pennsylvania
# 31          NJ      0.271468            New Jersey
# 17          KY      0.289206              Kentucky
# 28          ND      0.302957          North Dakota
# 22          MI      0.381450              Michigan
# 7           DC      0.395542  District of Columbia
# 39          SC      0.414978        South Carolina
# 47          WI      0.415042             Wisconsin
# 34          NY      0.441584              New York
# 48          WV      0.559489         West Virginia
# 9           FL      0.690109               Florida

# %% [markdown]
# ### Interesting Aggregates

# %%
agg_im= outage_df.pivot_table(index='NERC.REGION',columns='CAUSE.CATEGORY',values="IMPACT_SCORE",aggfunc='mean')
agg_im
# Out:
# CAUSE.CATEGORY  equipment failure  fuel supply emergency  intentional attack  \
# NERC.REGION
# ASCC                    -0.398372                    NaN                 NaN
# ECAR                    -0.230388                    NaN           -0.418185
# FRCC                    -0.160836                    NaN           -0.625005
# FRCC, SERC                    NaN                    NaN                 NaN
# HECO                          NaN                    NaN                 NaN
# HI                            NaN                    NaN                 NaN
# MRO                           NaN               0.775508           -0.376839
# NPCC                    -0.305414               1.033702           -0.592205
# PR                            NaN                    NaN                 NaN
# RFC                      0.732515               3.272634           -0.562378
# SERC                    -0.356173               1.087764           -0.577594
# SPP                     -0.217272              -0.669433           -0.578619
# TRE                     -0.372642               0.804090           -0.599756
# WECC                    -0.253889               0.456716           -0.567782
#
# CAUSE.CATEGORY  islanding  public appeal  severe weather  \
# NERC.REGION
# ASCC                  NaN            NaN             NaN
# ECAR                  NaN            NaN        0.518388
# FRCC                  NaN      -0.116905        1.447440
# FRCC, SERC            NaN            NaN             NaN
# HECO                  NaN            NaN       -0.031349
# HI                    NaN            NaN        0.324253
# MRO             -0.647669      -0.552291        0.049756
# NPCC            -0.545928      -0.310625        0.207407
# PR                    NaN            NaN       -0.480671
# RFC             -0.643695      -0.524463        0.282686
# SERC            -0.639618      -0.482630       -0.040207
# SPP             -0.586900      -0.511717        0.389341
# TRE                   NaN      -0.492202        0.549893
# WECC            -0.635749      -0.412674        0.598164
#
# CAUSE.CATEGORY  system operability disruption
# NERC.REGION
# ASCC                                      NaN
# ECAR                                 2.915342
# FRCC                                -0.496310
# FRCC, SERC                           0.050804
# HECO                                -0.566547
# HI                                        NaN
# MRO                                       NaN
# NPCC                                 0.783275
# PR                                        NaN
# RFC                                 -0.042438
# SERC                                -0.277758
# SPP                                  2.334783
# TRE                                 -0.029848
# WECC                                -0.131216

# %%
print(agg_im.to_markdown(index=True))
# Out:
# | NERC.REGION   |   equipment failure |   fuel supply emergency |   intentional attack |   islanding |   public appeal |   severe weather |   system operability disruption |
# |:--------------|--------------------:|------------------------:|---------------------:|------------:|----------------:|-----------------:|--------------------------------:|
# | ASCC          |           -0.398372 |              nan        |           nan        |  nan        |      nan        |      nan         |                     nan         |
# | ECAR          |           -0.230388 |              nan        |            -0.418185 |  nan        |      nan        |        0.518388  |                       2.91534   |
# | FRCC          |           -0.160836 |              nan        |            -0.625005 |  nan        |       -0.116905 |        1.44744   |                      -0.49631   |
# | FRCC, SERC    |          nan        |              nan        |           nan        |  nan        |      nan        |      nan         |                       0.0508044 |
# | HECO          |          nan        |              nan        |           nan        |  nan        |      nan        |       -0.031349  |                      -0.566547  |
# | HI            |          nan        |              nan        |           nan        |  nan        |      nan        |        0.324253  |                     nan         |
# | MRO           |          nan        |                0.775508 |            -0.376839 |   -0.647669 |       -0.552291 |        0.0497565 |                     nan         |
# | NPCC          |           -0.305414 |                1.0337   |            -0.592205 |   -0.545928 |       -0.310625 |        0.207407  |                       0.783275  |
# | PR            |          nan        |              nan        |           nan        |  nan        |      nan        |       -0.480671  |                     nan         |
# | RFC           |            0.732515 |                3.27263  |            -0.562378 |   -0.643695 |       -0.524463 |        0.282686  |                      -0.0424385 |
# | SERC          |           -0.356173 |                1.08776  |            -0.577594 |   -0.639618 |       -0.48263  |       -0.0402071 |                      -0.277758  |
# | SPP           |           -0.217272 |               -0.669433 |            -0.578619 |   -0.5869   |       -0.511717 |        0.389341  |                       2.33478   |
# | TRE           |           -0.372642 |                0.80409  |            -0.599756 |  nan        |       -0.492202 |        0.549893  |                      -0.0298481 |
# | WECC          |           -0.253889 |                0.456716 |            -0.567782 |   -0.635749 |       -0.412674 |        0.598164  |                      -0.131216  |

# %% [markdown]
# ## Step 3: Assessment of Missingness

# %%
def tvd_perm_test(df, column,column_missing):
    np.random.seed(22)
    n_repetitions = 1000
    shuffled = df.copy()
    col_missing = column_missing
    col = column
    shuffled[f'{col_missing}_IS_MISSING'] = shuffled[col_missing].isna()
    
    tvds = []
    for _ in range(n_repetitions):
        
    
        shuffled[col] = np.random.permutation(shuffled[col])
        
      
        pivoted = (
            shuffled
            .pivot_table(index=col, columns=f'{col_missing}_IS_MISSING', aggfunc='size')
        )
        
        pivoted = pivoted / pivoted.sum()
        
        tvd = pivoted.diff(axis=1).iloc[:, -1].abs().sum() / 2
        tvds.append(tvd)
    return tvds
def pivot_table(df, col, col_missing):
    df_copy = df.copy()
    df_copy[f'{col_missing}_IS_MISSING'] = df_copy[col_missing].isna()
    pv = df_copy.pivot_table(index=col, columns=f'{col_missing}_IS_MISSING', aggfunc='size',fill_value=0)
    pv = pv/pv.sum()
    return pv

# %%
for i in outage_df.columns:
    print(f"{i}: {outage_df[i].isna().sum()}")
# Out:
# U.S._STATE: 0
# POSTAL.CODE: 0
# NERC.REGION: 0
# CAUSE.CATEGORY: 0
# CLIMATE.REGION: 6
# ANOMALY.LEVEL: 9
# CLIMATE.CATEGORY: 9
# TOTAL.CUSTOMERS: 0
# TOTAL.PRICE: 22
# TOTAL.SALES: 22
# TOTAL.REALGSP: 0
# UTIL.REALGSP: 0
# UTIL.CONTRI: 0
# PC.REALGSP.REL: 0
# POPULATION: 0
# POPDEN_URBAN: 0
# MONTH: 9
# YEAR: 0
# OUTAGE.START: 9
# OUTAGE.RESTORATION: 58
# IMPACT_SCORE: 0

# %%
outage_df[outage_df['CLIMATE.REGION'].isna()]
# Out:
#      U.S._STATE POSTAL.CODE NERC.REGION                 CAUSE.CATEGORY  \
# 1516     Hawaii          HI          HI                 severe weather
# 1517     Hawaii          HI          PR                 severe weather
# 1518     Hawaii          HI        HECO                 severe weather
# 1519     Hawaii          HI        HECO  system operability disruption
# 1520     Hawaii          HI        HECO                 severe weather
# 1534     Alaska          AK        ASCC              equipment failure
#
#      CLIMATE.REGION  ANOMALY.LEVEL CLIMATE.CATEGORY  TOTAL.CUSTOMERS  \
# 1516            NaN           -0.7             cold         472025.0
# 1517            NaN           -0.4           normal         478272.0
# 1518            NaN            0.7             warm         463615.0
# 1519            NaN            0.0           normal         463615.0
# 1520            NaN            0.7             warm         463615.0
# 1534            NaN            NaN              NaN         273530.0
#
#       TOTAL.PRICE  TOTAL.SALES  TOTAL.REALGSP  UTIL.REALGSP  UTIL.CONTRI  \
# 1516        25.78     835405.0        67364.0        1646.0     2.443442
# 1517        31.29     852355.0        67686.0        1935.0     2.858789
# 1518        20.54     922915.0        65956.0        1436.0     2.177209
# 1519        21.45     891580.0        65956.0        1436.0     2.177209
# 1520        20.54     922915.0        65956.0        1436.0     2.177209
# 1534          NaN          NaN        36046.0         724.0     2.008545
#
#       PC.REALGSP.REL  POPULATION  POPDEN_URBAN  MONTH    YEAR  \
# 1516        1.044710   1332213.0        3180.8   12.0  2008.0
# 1517        1.032026   1378227.0        3180.8    5.0  2011.0
# 1518        1.029626   1309731.0        3180.8   10.0  2006.0
# 1519        1.029626   1309731.0        3180.8    6.0  2006.0
# 1520        1.029626   1309731.0        3180.8   10.0  2006.0
# 1534        1.282847    627963.0        1802.6    NaN  2000.0
#
#             OUTAGE.START  OUTAGE.RESTORATION  IMPACT_SCORE
# 1516 2008-12-26 18:13:00 2008-12-27 17:00:00      0.324253
# 1517 2011-05-02 17:06:00 2011-05-02 20:00:00     -0.480671
# 1518 2006-10-15 07:09:00 2006-10-15 16:12:00     -0.442686
# 1519 2006-06-01 14:12:00 2006-06-01 18:09:00     -0.566547
# 1520 2006-10-15 07:09:00 2006-10-16 14:55:00      0.379988
# 1534                 NaT                 NaT     -0.398372

# %%
outage_df[outage_df['U.S._STATE'] == 'Alaska']
# Out:
#      U.S._STATE POSTAL.CODE NERC.REGION     CAUSE.CATEGORY CLIMATE.REGION  \
# 1534     Alaska          AK        ASCC  equipment failure            NaN
#
#       ANOMALY.LEVEL CLIMATE.CATEGORY  TOTAL.CUSTOMERS  TOTAL.PRICE  \
# 1534            NaN              NaN         273530.0          NaN
#
#       TOTAL.SALES  TOTAL.REALGSP  UTIL.REALGSP  UTIL.CONTRI  PC.REALGSP.REL  \
# 1534          NaN        36046.0         724.0     2.008545        1.282847
#
#       POPULATION  POPDEN_URBAN  MONTH    YEAR OUTAGE.START OUTAGE.RESTORATION  \
# 1534    627963.0        1802.6    NaN  2000.0          NaT                NaT
#
#       IMPACT_SCORE
# 1534     -0.398372

# %%
outage_df[outage_df['TOTAL.SALES'].isna()].iloc[10:20]
# Out:
#           U.S._STATE POSTAL.CODE NERC.REGION                 CAUSE.CATEGORY  \
# 763   North Carolina          NC        SERC             intentional attack
# 767   North Carolina          NC        SERC                 severe weather
# 828           Oregon          OR        WECC             intentional attack
# 888         Delaware          DE         RFC  system operability disruption
# 901         Delaware          DE         RFC             intentional attack
# 1319        Virginia          VA        SERC              equipment failure
# 1420        Oklahoma          OK         SPP                 severe weather
# 1507          Kansas          KS         SPP                 severe weather
# 1521           Idaho          ID        WECC  system operability disruption
# 1529           Idaho          ID        WECC  system operability disruption
#
#      CLIMATE.REGION  ANOMALY.LEVEL CLIMATE.CATEGORY  TOTAL.CUSTOMERS  \
# 763       Southeast           -0.3           normal        5106195.0
# 767       Southeast            NaN              NaN        4105711.0
# 828       Northwest           -0.3           normal        1962944.0
# 888       Northeast            NaN              NaN         377219.0
# 901       Northeast           -0.3           normal         473473.0
# 1319      Southeast            NaN              NaN        3122909.0
# 1420          South           -0.3           normal        2033942.0
# 1507          South            NaN              NaN        1379347.0
# 1521      Northwest           -0.3           normal         849763.0
# 1529      Northwest           -0.3           normal         849763.0
#
#       TOTAL.PRICE  TOTAL.SALES  TOTAL.REALGSP  UTIL.REALGSP  UTIL.CONTRI  \
# 763           NaN          NaN       448866.0        7443.0     1.658179
# 767           NaN          NaN       341051.0        8262.0     2.422512
# 828           NaN          NaN       207367.0        3179.0     1.533031
# 888           NaN          NaN        50338.0        1016.0     2.018356
# 901           NaN          NaN        60570.0         947.0     1.563480
# 1319          NaN          NaN       337211.0        6978.0     2.069328
# 1420          NaN          NaN       174173.0        4334.0     2.488331
# 1507          NaN          NaN       109966.0        2462.0     2.238874
# 1521          NaN          NaN        60911.0         960.0     1.576070
# 1529          NaN          NaN        60911.0         960.0     1.576070
#
#       PC.REALGSP.REL  POPULATION  POPDEN_URBAN  MONTH    YEAR  \
# 763         0.872365  10156689.0        1367.2    7.0  2016.0
# 767         0.943144   8081614.0        1367.2    NaN  2000.0
# 828         1.001796   4085989.0        2804.9    7.0  2016.0
# 888         1.430618    786373.0        1838.3    NaN  2000.0
# 901         1.254994    952698.0        1838.3    7.0  2016.0
# 1319        1.060588   7105817.0        2265.2    NaN  2000.0
# 1420        0.876786   3921207.0        1901.7    7.0  2016.0
# 1507        0.898619   2713535.0        2176.5    NaN  2002.0
# 1521        0.715673   1680026.0        2216.8    7.0  2016.0
# 1529        0.715673   1680026.0        2216.8    7.0  2016.0
#
#             OUTAGE.START  OUTAGE.RESTORATION  IMPACT_SCORE
# 763  2016-07-07 05:53:00 2016-07-07 08:40:00     -0.619052
# 767                  NaT                 NaT     -0.204062
# 828  2016-07-02 04:00:00 2016-07-04 00:40:00     -0.303485
# 888                  NaT                 NaT      0.706756
# 901  2016-07-21 06:18:00 2016-07-21 14:45:00     -0.548645
# 1319                 NaT                 NaT      0.040699
# 1420 2016-07-14 14:44:00 2016-07-15 04:00:00     -0.306602
# 1507                 NaT                 NaT      0.502689
# 1521 2016-07-19 15:45:00 2016-07-19 19:29:00     -0.382543
# 1529 2016-07-19 15:45:00 2016-07-19 19:25:00     -0.264173

# %%
outage_df[outage_df['OUTAGE.START'].isna()]
# Out:
#           U.S._STATE POSTAL.CODE NERC.REGION                 CAUSE.CATEGORY  \
# 240            Texas          TX        FRCC              equipment failure
# 340          Alabama          AL        SERC                 severe weather
# 366         Illinois          IL        SERC                 severe weather
# 767   North Carolina          NC        SERC                 severe weather
# 888         Delaware          DE         RFC  system operability disruption
# 1319        Virginia          VA        SERC              equipment failure
# 1507          Kansas          KS         SPP                 severe weather
# 1531    North Dakota          ND         MRO          fuel supply emergency
# 1534          Alaska          AK        ASCC              equipment failure
#
#           CLIMATE.REGION  ANOMALY.LEVEL CLIMATE.CATEGORY  TOTAL.CUSTOMERS  \
# 240                South            NaN              NaN        9299829.0
# 340            Southeast            NaN              NaN        2262753.0
# 366              Central            NaN              NaN        5282401.0
# 767            Southeast            NaN              NaN        4105711.0
# 888            Northeast            NaN              NaN         377219.0
# 1319           Southeast            NaN              NaN        3122909.0
# 1507               South            NaN              NaN        1379347.0
# 1531  West North Central            NaN              NaN         366037.0
# 1534                 NaN            NaN              NaN         273530.0
#
#       TOTAL.PRICE  TOTAL.SALES  TOTAL.REALGSP  UTIL.REALGSP  UTIL.CONTRI  \
# 240           NaN          NaN       944631.0       30908.0     3.271965
# 340           NaN          NaN       150090.0        5704.0     3.800386
# 366           NaN          NaN       612709.0       15815.0     2.581160
# 767           NaN          NaN       341051.0        8262.0     2.422512
# 888           NaN          NaN        50338.0        1016.0     2.018356
# 1319          NaN          NaN       337211.0        6978.0     2.069328
# 1507          NaN          NaN       109966.0        2462.0     2.238874
# 1531          NaN          NaN        27868.0        1019.0     3.656524
# 1534          NaN          NaN        36046.0         724.0     2.008545
#
#       PC.REALGSP.REL  POPULATION  POPDEN_URBAN  MONTH    YEAR OUTAGE.START  \
# 240         1.007979  20944499.0        2435.3    NaN  2000.0          NaT
# 340         0.753425   4452173.0        1278.5    NaN  2000.0          NaT
# 366         1.101263  12434161.0        2877.6    NaN  2000.0          NaT
# 767         0.943144   8081614.0        1367.2    NaN  2000.0          NaT
# 888         1.430618    786373.0        1838.3    NaN  2000.0          NaT
# 1319        1.060588   7105817.0        2265.2    NaN  2000.0          NaT
# 1507        0.898619   2713535.0        2176.5    NaN  2002.0          NaT
# 1531        0.877405    649422.0        2192.2    NaN  2006.0          NaT
# 1534        1.282847    627963.0        1802.6    NaN  2000.0          NaT
#
#      OUTAGE.RESTORATION  IMPACT_SCORE
# 240                 NaT     -0.325723
# 340                 NaT      0.185409
# 366                 NaT     -0.217359
# 767                 NaT     -0.204062
# 888                 NaT      0.706756
# 1319                NaT      0.040699
# 1507                NaT      0.502689
# 1531                NaT      1.099987
# 1534                NaT     -0.398372

# %%
outage_df[outage_df['OUTAGE.RESTORATION'].isna()]
# Out:
#           U.S._STATE POSTAL.CODE NERC.REGION                 CAUSE.CATEGORY  \
# 23         Tennessee          TN        SERC             intentional attack
# 37         Tennessee          TN        SERC  system operability disruption
# 48         Tennessee          TN        SERC             intentional attack
# 50         Wisconsin          WI         MRO          fuel supply emergency
# 183            Texas          TX        WECC          fuel supply emergency
# 193            Texas          TX         TRE          fuel supply emergency
# 233            Texas          TX         TRE          fuel supply emergency
# 240            Texas          TX        FRCC              equipment failure
# 283            Texas          TX         TRE                 severe weather
# 302          Indiana          IN        ECAR              equipment failure
# 340          Alabama          AL        SERC                 severe weather
# 351         Illinois          IL        SERC                 severe weather
# 366         Illinois          IL        SERC                 severe weather
# 428       Washington          WA        WECC             intentional attack
# 431       Washington          WA        WECC                 severe weather
# 433       Washington          WA        WECC                 severe weather
# 444       Washington          WA        WECC                 severe weather
# 457       Washington          WA        WECC             intentional attack
# 458       Washington          WA        WECC                 severe weather
# 459       Washington          WA        WECC                      islanding
# 468       Washington          WA        WECC                      islanding
# 506          Arizona          AZ        WECC             intentional attack
# 509          Arizona          AZ        WECC             intentional attack
# 513          Arizona          AZ        WECC             intentional attack
# 690             Ohio          OH        ECAR              equipment failure
# 767   North Carolina          NC        SERC                 severe weather
# 776       New Jersey          NJ         RFC             intentional attack
# 781       New Jersey          NJ        NPCC                 severe weather
# 798       New Jersey          NJ         RFC             intentional attack
# 824           Oregon          OR        WECC             intentional attack
# 857         Missouri          MO        SERC             intentional attack
# 864         Missouri          MO        SERC             intentional attack
# 888         Delaware          DE         RFC  system operability disruption
# 956         New York          NY        NPCC             intentional attack
# 1005       Louisiana          LA        SERC                 severe weather
# 1025       Louisiana          LA         SPP                 severe weather
# 1103      California          CA        WECC          fuel supply emergency
# 1112      California          CA        WECC          fuel supply emergency
# 1139      California          CA        WECC          fuel supply emergency
# 1181      California          CA        WECC                 severe weather
# 1192      California          CA        WECC  system operability disruption
# 1196      California          CA        WECC                 severe weather
# 1200      California          CA        WECC          fuel supply emergency
# 1214      California          CA        WECC  system operability disruption
# 1241      California          CA        WECC          fuel supply emergency
# 1260      California          CA        WECC                 severe weather
# 1277      California          CA        WECC          fuel supply emergency
# 1282      California          CA        WECC          fuel supply emergency
# 1319        Virginia          VA        SERC              equipment failure
# 1419        Oklahoma          OK         SPP                 severe weather
# 1422        Oklahoma          OK         SPP                 severe weather
# 1464           Maine          ME        NPCC             intentional attack
# 1494        Colorado          CO        WECC          fuel supply emergency
# 1507          Kansas          KS         SPP                 severe weather
# 1514          Kansas          KS         SPP                 severe weather
# 1528           Idaho          ID        WECC             intentional attack
# 1531    North Dakota          ND         MRO          fuel supply emergency
# 1534          Alaska          AK        ASCC              equipment failure
#
#           CLIMATE.REGION  ANOMALY.LEVEL CLIMATE.CATEGORY  TOTAL.CUSTOMERS  \
# 23               Central            1.2             warm        3260708.0
# 37               Central           -0.3           normal        3293512.0
# 48               Central            1.1             warm        3293512.0
# 50    East North Central            0.0           normal        2982802.0
# 183                South           -0.9             cold       10748834.0
# 193                South           -0.2           normal       11672996.0
# 233                South            0.0           normal       11672996.0
# 240                South            NaN              NaN        9299829.0
# 283                South            2.3             warm       11849725.0
# 302              Central           -0.5             cold        2865343.0
# 340            Southeast            NaN              NaN        2262753.0
# 351              Central           -0.7             cold        5282401.0
# 366              Central            NaN              NaN        5282401.0
# 428            Northwest            1.6             warm        3382664.0
# 431            Northwest            1.6             warm        3382664.0
# 433            Northwest            1.4             warm        3340024.0
# 444            Northwest            2.2             warm        3340024.0
# 457            Northwest            1.6             warm        3382664.0
# 458            Northwest            2.2             warm        3340024.0
# 459            Northwest            1.2             warm        3340024.0
# 468            Northwest            0.6             warm        3382664.0
# 506            Southwest            0.2           normal        2351763.0
# 509            Southwest           -0.5             cold        2981625.0
# 513            Southwest           -0.7             cold        2193562.0
# 690              Central           -0.7             cold        5261626.0
# 767            Southeast            NaN              NaN        4105711.0
# 776            Northeast           -0.5             cold        3994528.0
# 781            Northeast            1.0             warm        4014202.0
# 798            Northeast           -0.5             cold        3994528.0
# 824            Northwest            2.0             warm        1962944.0
# 857              Central            2.3             warm        3118394.0
# 864              Central            0.6             warm        3138342.0
# 888            Northeast            NaN              NaN         377219.0
# 956            Northeast            2.0             warm        8199451.0
# 1005               South            0.6             warm        2368711.0
# 1025               South            1.1             warm        2110768.0
# 1103                West            1.0             warm       15214454.0
# 1112                West           -0.4           normal       14826792.0
# 1139                West           -0.2           normal       15107549.0
# 1181                West           -0.1           normal       15079226.0
# 1192                West           -0.4           normal       13530807.0
# 1196                West            0.5             warm       15214454.0
# 1200                West           -0.1           normal       14789510.0
# 1214                West           -0.7             cold       12537831.0
# 1241                West            2.0             warm       15286023.0
# 1260                West           -0.1           normal       15079226.0
# 1277                West            0.3           normal       15010483.0
# 1282                West           -0.3           normal       14684071.0
# 1319           Southeast            NaN              NaN        3122909.0
# 1419               South            2.3             warm        2020012.0
# 1422               South            2.2             warm        2020012.0
# 1464           Northeast           -1.1             cold         770617.0
# 1494           Southwest            0.2           normal        2349921.0
# 1507               South            NaN              NaN        1379347.0
# 1514               South            1.0             warm        1484396.0
# 1528           Northwest            1.6             warm         849763.0
# 1531  West North Central            NaN              NaN         366037.0
# 1534                 NaN            NaN              NaN         273530.0
#
#       TOTAL.PRICE  TOTAL.SALES  TOTAL.REALGSP  UTIL.REALGSP  UTIL.CONTRI  \
# 23           9.70    9499547.0       282752.0        1692.0     0.598404
# 37            NaN          NaN       290712.0        1813.0     0.623641
# 48           8.80    6776403.0       290712.0        1813.0     0.623641
# 50          10.98    5757447.0       268742.0        4680.0     1.741447
# 183         10.30   33193019.0      1169399.0       27695.0     2.368311
# 193          8.55   27846934.0      1421759.0       28121.0     1.977902
# 233          9.20   34707247.0      1421759.0       28121.0     1.977902
# 240           NaN          NaN       944631.0       30908.0     3.271965
# 283          8.20   28745852.0      1488049.0       31256.0     2.100468
# 302          5.39    9080103.0       251606.0        6964.0     2.767820
# 340           NaN          NaN       150090.0        5704.0     3.800386
# 351          6.94   10513961.0       612709.0       15815.0     2.581160
# 366           NaN          NaN       612709.0       15815.0     2.581160
# 428          7.74    7797125.0       420809.0        3504.0     0.832682
# 431          7.74    7797125.0       420809.0        3504.0     0.832682
# 433          7.42    7190121.0       404972.0        3461.0     0.854627
# 444          7.75    7302488.0       404972.0        3461.0     0.854627
# 457          7.74    7797125.0       420809.0        3504.0     0.832682
# 458          7.75    7302488.0       404972.0        3461.0     0.854627
# 459          7.52    7372409.0       404972.0        3461.0     0.854627
# 468          7.48    6669170.0       420809.0        3504.0     0.832682
# 506          6.65    4330353.0       212543.0        4972.0     2.339291
# 509          9.27    5549419.0       258744.0        5365.0     2.073478
# 513          7.43    5170548.0       202536.0        5745.0     2.836533
# 690          6.83   14083913.0       480907.0       12475.0     2.594057
# 767           NaN          NaN       341051.0        8262.0     2.422512
# 776         14.36    6578782.0       499117.0        9818.0     1.967074
# 781         14.64    6614106.0       503515.0        9269.0     1.840859
# 798         14.36    6578782.0       499117.0        9818.0     1.967074
# 824          8.86    3856593.0       207367.0        3179.0     1.533031
# 857          8.78    6433254.0       259820.0        4975.0     1.914787
# 864          9.88    5493089.0       260309.0        5195.0     1.995705
# 888           NaN          NaN        50338.0        1016.0     2.018356
# 956         13.64   11855894.0      1279883.0       18427.0     1.439741
# 1005         7.20    6672269.0       208252.0        3809.0     1.829034
# 1025         6.13    7154368.0       189128.0        4988.0     2.637367
# 1103        16.20   21901510.0      2249711.0       26426.0     1.174640
# 1112        13.62   26288469.0      2002744.0       29081.0     1.452058
# 1139        13.80   21327504.0      2055578.0       27856.0     1.355142
# 1181        14.47   20712609.0      2118858.0       26449.0     1.248267
# 1192         9.89   21351409.0      1647632.0       18761.0     1.138664
# 1196        14.39   18076185.0      2249711.0       26426.0     1.174640
# 1200        12.17   19983832.0      1913674.0       27376.0     1.430547
# 1214         9.81   21784929.0      1653021.0       29581.0     1.789511
# 1241        14.53   18411708.0      2317466.0       27735.0     1.196781
# 1260        14.47   20712609.0      2118858.0       26449.0     1.248267
# 1277        15.51   24117856.0      2004400.0       27150.0     1.354520
# 1282        13.66   22041117.0      1994044.0       29272.0     1.467972
# 1319          NaN          NaN       337211.0        6978.0     2.069328
# 1419         7.01    4622775.0       181045.0        4198.0     2.318761
# 1422         7.25    4231978.0       181045.0        4198.0     2.318761
# 1464         9.97     864735.0        46233.0        1095.0     2.368438
# 1494         7.77    4074285.0       240150.0        3178.0     1.323340
# 1507          NaN          NaN       109966.0        2462.0     2.238874
# 1514        10.48    3722254.0       135967.0        2290.0     1.684232
# 1528         8.05    1657605.0        60911.0         960.0     1.576070
# 1531          NaN          NaN        27868.0        1019.0     3.656524
# 1534          NaN          NaN        36046.0         724.0     2.008545
#
#       PC.REALGSP.REL  POPULATION  POPDEN_URBAN  MONTH    YEAR  \
# 23          0.851798   6600299.0        1450.3    7.0  2015.0
# 37          0.863008   6649404.0        1450.3    7.0  2016.0
# 48          0.863008   6649404.0        1450.3    4.0  2016.0
# 50          0.950806   5759432.0        2123.3    6.0  2014.0
# 183         0.998819  23831983.0        2435.3    9.0  2007.0
# 193         1.074372  26979078.0        2435.3    4.0  2014.0
# 233         1.074372  26979078.0        2435.3    6.0  2014.0
# 240         1.007979  20944499.0        2435.3    NaN  2000.0
# 283         1.077502  27469114.0        2435.3   12.0  2015.0
# 302         0.923053   6091866.0        1860.0    8.0  2000.0
# 340         0.753425   4452173.0        1278.5    NaN  2000.0
# 351         1.101263  12434161.0        2877.6    5.0  2000.0
# 366         1.101263  12434161.0        2877.6    NaN  2000.0
# 428         1.140861   7280934.0        2380.0    3.0  2016.0
# 431         1.140861   7280934.0        2380.0    3.0  2016.0
# 433         1.111528   7170351.0        2380.0    8.0  2015.0
# 444         1.111528   7170351.0        2380.0   11.0  2015.0
# 457         1.140861   7280934.0        2380.0    3.0  2016.0
# 458         1.111528   7170351.0        2380.0   11.0  2015.0
# 459         1.111528   7170351.0        2380.0    7.0  2015.0
# 468         1.140861   7280934.0        2380.0    5.0  2016.0
# 506         0.873384   5396255.0        2625.4    4.0  2002.0
# 509         0.782995   6728783.0        2625.4    1.0  2014.0
# 513         0.877126   5160586.0        2625.4    5.0  2000.0
# 690         0.945804  11363543.0        2033.7    6.0  2000.0
# 767         0.943144   8081614.0        1367.2    NaN  2000.0
# 776         1.137500   8938844.0        2851.2    1.0  2014.0
# 781         1.137970   8958013.0        2851.2    6.0  2015.0
# 798         1.137500   8938844.0        2851.2    1.0  2014.0
# 824         1.001796   4085989.0        2804.9    2.0  2016.0
# 857         0.862371   6083672.0        2053.5   12.0  2015.0
# 864         0.843585   6091176.0        2053.5    5.0  2016.0
# 888         1.430618    786373.0        1838.3    NaN  2000.0
# 956         1.273628  19836286.0        4161.4    2.0  2016.0
# 1005        0.877221   4686157.0        1685.8    5.0  2016.0
# 1025        0.932523   4497267.0        1685.8   10.0  2002.0
# 1103        1.130828  39144818.0        4303.7    6.0  2015.0
# 1112        1.130411  36604337.0        4303.7    7.0  2008.0
# 1139        1.105195  38414128.0        4303.7    5.0  2013.0
# 1181        1.112342  38792291.0        4303.7    5.0  2014.0
# 1192        1.068584  34479458.0        4303.7    3.0  2001.0
# 1196        1.130828  39144818.0        4303.7    2.0  2015.0
# 1200        1.109147  36961229.0        4303.7    4.0  2009.0
# 1214        1.086937  33987977.0        4303.7    6.0  2000.0
# 1241        1.164114  39296476.0        4303.7    2.0  2016.0
# 1260        1.112342  38792291.0        4303.7    5.0  2014.0
# 1277        1.093529  38056055.0        4303.7    9.0  2012.0
# 1282        1.119733  36250311.0        4303.7    6.0  2007.0
# 1319        1.060588   7105817.0        2265.2    NaN  2000.0
# 1419        0.878501   3911338.0        1901.7   12.0  2015.0
# 1422        0.878501   3911338.0        1901.7   11.0  2015.0
# 1464        0.809074   1277072.0        1428.0    3.0  2000.0
# 1494        1.078124   4631888.0        2836.1    6.0  2005.0
# 1507        0.898619   2713535.0        2176.5    NaN  2002.0
# 1514        0.914012   2911641.0        2176.5    6.0  2015.0
# 1528        0.715673   1680026.0        2216.8    3.0  2016.0
# 1531        0.877405    649422.0        2192.2    NaN  2006.0
# 1534        1.282847    627963.0        1802.6    NaN  2000.0
#
#             OUTAGE.START OUTAGE.RESTORATION  IMPACT_SCORE
# 23   2015-07-30 13:00:00                NaT     -0.571327
# 37   2016-07-13 15:00:00                NaT     -0.004068
# 48   2016-04-27 13:36:00                NaT     -0.575792
# 50   2014-06-27 13:21:00                NaT      1.564227
# 183  2007-09-06 20:00:00                NaT      1.256561
# 193  2014-04-03 00:00:00                NaT      0.752757
# 233  2014-06-06 13:00:00                NaT      0.321147
# 240                  NaT                NaT     -0.325723
# 283  2015-12-26 19:30:00                NaT     -0.031025
# 302  2000-08-28 23:00:00                NaT     -0.263195
# 340                  NaT                NaT      0.185409
# 351  2000-05-18 18:00:00                NaT      0.060533
# 366                  NaT                NaT     -0.217359
# 428  2016-03-13 14:00:00                NaT     -0.573986
# 431  2016-03-01 15:00:00                NaT     -0.071663
# 433  2015-08-29 10:00:00                NaT      1.197763
# 444  2015-11-17 09:00:00                NaT      0.027059
# 457  2016-03-13 16:55:00                NaT     -0.584184
# 458  2015-11-17 10:00:00                NaT      0.690896
# 459  2015-07-31 10:55:00                NaT     -0.630132
# 468  2016-05-08 09:12:00                NaT     -0.625995
# 506  2002-04-08 15:00:00                NaT     -0.626185
# 509  2014-01-30 15:00:00                NaT     -0.605029
# 513  2000-05-31 01:15:00                NaT     -0.611155
# 690  2000-06-14 15:45:00                NaT     -0.197580
# 767                  NaT                NaT     -0.204062
# 776  2014-01-21 17:00:00                NaT     -0.490631
# 781  2015-06-23 18:26:00                NaT      0.128338
# 798  2014-01-26 23:00:00                NaT     -0.527070
# 824  2016-02-07 14:58:00                NaT     -0.584498
# 857  2015-12-31 11:00:00                NaT     -0.513560
# 864  2016-05-24 08:00:00                NaT     -0.577483
# 888                  NaT                NaT      0.706756
# 956  2016-02-07 11:30:00                NaT     -0.565610
# 1005 2016-05-20 01:15:00                NaT      0.032051
# 1025 2002-10-03 03:33:00                NaT      0.507127
# 1103 2015-06-08 00:00:00                NaT      1.544959
# 1112 2008-07-02 16:00:00                NaT      0.310369
# 1139 2013-05-13 12:52:00                NaT      0.987295
# 1181 2014-05-14 15:34:00                NaT     -0.417600
# 1192 2001-03-19 11:50:00                NaT      0.626041
# 1196 2015-02-06 20:58:00                NaT     -0.017062
# 1200 2009-04-23 00:00:00                NaT      0.611263
# 1214 2000-06-14 13:13:00                NaT     -0.512394
# 1241 2016-02-26 00:01:00                NaT      0.786801
# 1260 2014-05-15 10:43:00                NaT      3.780809
# 1277 2012-09-06 04:45:00                NaT      1.199134
# 1282 2007-06-01 13:00:00                NaT      1.014250
# 1319                 NaT                NaT      0.040699
# 1419 2015-12-27 17:00:00                NaT     -0.033030
# 1422 2015-11-28 06:00:00                NaT     -0.155746
# 1464 2000-03-14 21:06:00                NaT     -0.594379
# 1494 2005-06-28 11:30:00                NaT      1.544513
# 1507                 NaT                NaT      0.502689
# 1514 2015-06-26 02:00:00                NaT      0.153122
# 1528 2016-03-01 13:35:00                NaT     -0.522110
# 1531                 NaT                NaT      1.099987
# 1534                 NaT                NaT     -0.398372

# %%
outage_df[outage_df['MONTH'].isna()]
# Out:
#           U.S._STATE POSTAL.CODE NERC.REGION                 CAUSE.CATEGORY  \
# 240            Texas          TX        FRCC              equipment failure
# 340          Alabama          AL        SERC                 severe weather
# 366         Illinois          IL        SERC                 severe weather
# 767   North Carolina          NC        SERC                 severe weather
# 888         Delaware          DE         RFC  system operability disruption
# 1319        Virginia          VA        SERC              equipment failure
# 1507          Kansas          KS         SPP                 severe weather
# 1531    North Dakota          ND         MRO          fuel supply emergency
# 1534          Alaska          AK        ASCC              equipment failure
#
#           CLIMATE.REGION  ANOMALY.LEVEL CLIMATE.CATEGORY  TOTAL.CUSTOMERS  \
# 240                South            NaN              NaN        9299829.0
# 340            Southeast            NaN              NaN        2262753.0
# 366              Central            NaN              NaN        5282401.0
# 767            Southeast            NaN              NaN        4105711.0
# 888            Northeast            NaN              NaN         377219.0
# 1319           Southeast            NaN              NaN        3122909.0
# 1507               South            NaN              NaN        1379347.0
# 1531  West North Central            NaN              NaN         366037.0
# 1534                 NaN            NaN              NaN         273530.0
#
#       TOTAL.PRICE  TOTAL.SALES  TOTAL.REALGSP  UTIL.REALGSP  UTIL.CONTRI  \
# 240           NaN          NaN       944631.0       30908.0     3.271965
# 340           NaN          NaN       150090.0        5704.0     3.800386
# 366           NaN          NaN       612709.0       15815.0     2.581160
# 767           NaN          NaN       341051.0        8262.0     2.422512
# 888           NaN          NaN        50338.0        1016.0     2.018356
# 1319          NaN          NaN       337211.0        6978.0     2.069328
# 1507          NaN          NaN       109966.0        2462.0     2.238874
# 1531          NaN          NaN        27868.0        1019.0     3.656524
# 1534          NaN          NaN        36046.0         724.0     2.008545
#
#       PC.REALGSP.REL  POPULATION  POPDEN_URBAN  MONTH    YEAR OUTAGE.START  \
# 240         1.007979  20944499.0        2435.3    NaN  2000.0          NaT
# 340         0.753425   4452173.0        1278.5    NaN  2000.0          NaT
# 366         1.101263  12434161.0        2877.6    NaN  2000.0          NaT
# 767         0.943144   8081614.0        1367.2    NaN  2000.0          NaT
# 888         1.430618    786373.0        1838.3    NaN  2000.0          NaT
# 1319        1.060588   7105817.0        2265.2    NaN  2000.0          NaT
# 1507        0.898619   2713535.0        2176.5    NaN  2002.0          NaT
# 1531        0.877405    649422.0        2192.2    NaN  2006.0          NaT
# 1534        1.282847    627963.0        1802.6    NaN  2000.0          NaT
#
#      OUTAGE.RESTORATION  IMPACT_SCORE
# 240                 NaT     -0.325723
# 340                 NaT      0.185409
# 366                 NaT     -0.217359
# 767                 NaT     -0.204062
# 888                 NaT      0.706756
# 1319                NaT      0.040699
# 1507                NaT      0.502689
# 1531                NaT      1.099987
# 1534                NaT     -0.398372

# %%
obs_pivot_o = pivot_table(outage_df, 'CAUSE.CATEGORY', 'OUTAGE.RESTORATION')

obs_stat_o = obs_pivot_o.diff(axis=1).iloc[:, -1].abs().sum() / 2
obs_stat_o
# Out:
# 0.2520091580226147

# %%
cause_dist = obs_pivot_o.plot(kind='barh', title='Cause Category by Missingness of Outage Restoration', barmode='group')

cause_dist.update_layout(
    width=800,  
    height=600   
)

# %%
tvds_o = tvd_perm_test(outage_df, 'CAUSE.CATEGORY', 'OUTAGE.RESTORATION')

# %%
(tvds_o >= obs_stat_o).mean()
# Out:
# 0.002

# %%
fig = px.histogram(pd.DataFrame({'tvds':tvds_o}),histnorm='probability', 
                   title='Empirical Distribution of the TVD')
fig.add_vline(x=obs_stat_o, line_color='red', line_width=2, opacity=1)
fig.add_annotation(text=f'<span style="color:red">Observed TVD = {round(obs_stat_o, 2)}</span>',
                   x=0.95 * obs_stat_o, showarrow=False, y=0.09)
#fig.update_layout(yaxis_range=[0, 0.1])
#fig.update_layout(xaxis_range=[0, 0.1])
fig.update_layout(showlegend=False)
fig.update_layout(
    xaxis_title="Generated TVDs"  
)
fig.update_layout(
    width=800,  
    height=600   
)

# %%
obs_pivot_month = pivot_table(outage_df, 'MONTH', 'OUTAGE.RESTORATION')

obs_stat_month= obs_pivot_month.diff(axis=1).iloc[:, -1].abs().sum() / 2
obs_stat_month
# Out:
# 0.22267850229522704

# %%
tvds_month = tvd_perm_test(outage_df, 'MONTH', 'OUTAGE.RESTORATION')

# %%
(tvds_month >= obs_stat_month).mean()
# Out:
# 0.09

# %%
fig = px.histogram(pd.DataFrame({'tvds':tvds_month}),histnorm='probability', 
                   title='Empirical Distribution of the TVD')
fig.add_vline(x=obs_stat_month, line_color='red', line_width=2, opacity=1)
fig.add_annotation(text=f'<span style="color:red">Observed TVD = {round(obs_stat_month, 2)}</span>',
                   x=0.9 * obs_stat_month, showarrow=False, y=0.09)
#fig.update_layout(yaxis_range=[0, 0.1])
#fig.update_layout(xaxis_range=[0, 0.1])
fig.update_layout(showlegend=False)
fig.update_layout(
    xaxis_title="Generated TVDs"  
)
fig.update_layout(
    width=800,  
    height=600   
)

# %%
o = obs_pivot_month.plot(kind='barh', title='Month by Missingness of Outage Restoration', barmode='group')

o.update_layout(
    width=800,  
    height=600   
)

# %% [markdown]
# ## Step 4: Hypothesis Testing

# %% [markdown]
# Null Hypothesis: The average Impact Score when the Climate is normal the same as the average Impact Score when climate is warm or cold.
#
# Alternate Hypothesis: The average Impact Score when climate is warm or cold is higher than when climate is normal.
#
# Test Statistic: Mean of impact score in abnormal(hot or cold) climate - Mean of impact score in normal climate.

# %%
outage_df['CAUSE.CATEGORY'].value_counts()
# Out:
# CAUSE.CATEGORY
# severe weather                   763
# intentional attack               418
# system operability disruption    127
# public appeal                     69
# equipment failure                 60
# fuel supply emergency             51
# islanding                         46
# Name: count, dtype: int64

# %%
weather_df = outage_df[outage_df['CAUSE.CATEGORY']=='severe weather'][['CLIMATE.CATEGORY','IMPACT_SCORE']] # only severe weather
weather_df['CLIMATE.CATEGORY'].value_counts()
# Out:
# CLIMATE.CATEGORY
# normal    354
# cold      239
# warm      166
# Name: count, dtype: int64

# %%
weather_df['CLIMATE.CATEGORY'] = weather_df['CLIMATE.CATEGORY'].apply(lambda x:'abnormal' if x in ['cold','warm']else x)

# %%
means_df = weather_df.groupby('CLIMATE.CATEGORY')['IMPACT_SCORE'].mean()
obs_stat_w = means_df.loc['abnormal'] - means_df.loc['normal']

# %%
def mean_perm_test(df, col1,col2):
    np.random.seed(22)
    n_repetitions = 5000
    shuffled = df.copy()
       
    mean_stats = []
    for _ in range(n_repetitions):
        
    
        shuffled[col2] = np.random.permutation(shuffled[col2])
        
        means_df = shuffled.groupby('CLIMATE.CATEGORY')[col2].mean()
        stat = means_df.loc['abnormal'] - means_df.loc['normal']

        mean_stats.append(stat)
    return  mean_stats

# %%
mean_stats = mean_perm_test(weather_df,'CLIMATE.CATEGORY','IMPACT_SCORE')

# %%
(mean_stats >= obs_stat_w).mean()
# Out:
# 0.8266

# %%
fig = px.histogram(pd.DataFrame({'mean_stats':mean_stats}),histnorm='probability',
                   title='Empirical Distribution of Difference of Means Statistic')
fig.add_vline(x=obs_stat_w, line_color='red', line_width=2, opacity=1)
fig.add_annotation(text=f'<span style="color:red">Observed TVD = {round(obs_stat_w, 2)}</span>',
                   x=1.8 * obs_stat_w, showarrow=False, y=0.06)
fig.update_layout(yaxis_range=[0, 0.06])
fig.update_layout(showlegend=False)
fig.update_layout(
    xaxis_title="Generated Test Statistics"  
)
fig.update_layout(
    width=800,  
    height=600   
)

# %% [markdown]
# We get a very high p-value: 0.8266. So, we fail to reject the null hypothesis.
#
# Also, I tried doing mean normal - abnormal, resulting in 0.1734 p-value, still failing to reject null hypothesis.
#
# Lastly, I tried doing it with absolute difference of mean, resulting in 0.3586 p-value, still failing to reject null hypothesis.

# %% [markdown]
# ## Step 5: Framing a Prediction Problem

# %% [markdown]
# Prediction Problem: Predict Impact Score of a power outage. Since Impact Score is numerical, this would be a regression model.

# %%
pd.set_option('display.max_columns', None)
possible_feature_cols = (['U.S._STATE', 'NERC.REGION', 'CAUSE.CATEGORY', 'ANOMALY.LEVEL',
                          'CLIMATE.REGION','TOTAL.CUSTOMERS','TOTAL.PRICE', 'TOTAL.SALES', 
                          'TOTAL.REALGSP','UTIL.REALGSP','UTIL.CONTRI',
                          'POPULATION', 'POPDEN_URBAN', 'MONTH', 'YEAR','OUTAGE.START'])
outage_focus_df = outage_df[possible_feature_cols + ["IMPACT_SCORE"]].dropna() #only 27 rows lost:
#will not impact model results much since the size is big relative to what was dropped

outage_focus_df
# Out:
#         U.S._STATE NERC.REGION      CAUSE.CATEGORY  ANOMALY.LEVEL  \
# 1        Minnesota         MRO      severe weather           -0.3
# 2        Minnesota         MRO  intentional attack           -0.1
# 3        Minnesota         MRO      severe weather           -1.5
# 4        Minnesota         MRO      severe weather           -0.1
# 5        Minnesota         MRO      severe weather            1.2
# ...            ...         ...                 ...            ...
# 1527         Idaho        WECC  intentional attack            1.6
# 1528         Idaho        WECC  intentional attack            1.6
# 1530  North Dakota         MRO       public appeal           -0.9
# 1532  South Dakota         RFC           islanding            0.5
# 1533  South Dakota         MRO           islanding            0.5
#
#           CLIMATE.REGION  TOTAL.CUSTOMERS  TOTAL.PRICE  TOTAL.SALES  \
# 1     East North Central        2595696.0         9.28    6562520.0
# 2     East North Central        2640737.0         9.28    5284231.0
# 3     East North Central        2586905.0         8.15    5222116.0
# 4     East North Central        2606813.0         9.19    5787064.0
# 5     East North Central        2673531.0        10.43    5970339.0
# ...                  ...              ...          ...          ...
# 1527           Northwest         849763.0         8.05    1657605.0
# 1528           Northwest         849763.0         8.05    1657605.0
# 1530  West North Central         394394.0         7.56    1313678.0
# 1532  West North Central         436229.0         7.67     924051.0
# 1533  West North Central         436229.0         7.67     924051.0
#
#       TOTAL.REALGSP  UTIL.REALGSP  UTIL.CONTRI  POPULATION  POPDEN_URBAN  \
# 1          274182.0        4802.0     1.751391   5348119.0        2279.0
# 2          291955.0        5226.0     1.790002   5457125.0        2279.0
# 3          267895.0        4571.0     1.706266   5310903.0        2279.0
# 4          277627.0        5364.0     1.932089   5380443.0        2279.0
# 5          292023.0        4873.0     1.668704   5489594.0        2279.0
# ...             ...           ...          ...         ...           ...
# 1527        60911.0         960.0     1.576070   1680026.0        2216.8
# 1528        60911.0         960.0     1.576070   1680026.0        2216.8
# 1530        39067.0         934.0     2.390765    685326.0        2192.2
# 1532        36504.0         606.0     1.660092    807067.0        2038.3
# 1533        36504.0         606.0     1.660092    807067.0        2038.3
#
#       MONTH    YEAR        OUTAGE.START  IMPACT_SCORE
# 1       7.0  2011.0 2011-07-01 17:00:00     -0.113518
# 2       5.0  2014.0 2014-05-11 18:38:00     -0.638695
# 3      10.0  2010.0 2010-10-26 20:00:00     -0.120676
# 4       6.0  2012.0 2012-06-19 04:30:00     -0.179503
# 5       7.0  2015.0 2015-07-18 02:00:00      0.243088
# ...     ...     ...                 ...           ...
# 1527    3.0  2016.0 2016-03-08 00:00:00     -0.569258
# 1528    3.0  2016.0 2016-03-01 13:35:00     -0.522110
# 1530   12.0  2011.0 2011-12-06 08:00:00     -0.494073
# 1532    8.0  2009.0 2009-08-29 22:54:00     -0.655477
# 1533    8.0  2009.0 2009-08-29 11:00:00     -0.633210
#
# [1507 rows x 17 columns]

# %% [markdown]
# ## Step 6: Baseline Model

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
def results(pipeline, X_train,X_test,y_train,y_test):

    y_pred_train2 = pipeline.predict(X_train)
    y_pred_test2 = pipeline.predict(X_test)

    rmse_train= root_mean_squared_error(y_train, y_pred_train2)
    r2_train = r2_score(y_train, y_pred_train2)

    rmse_test = root_mean_squared_error(y_test, y_pred_test2)
    r2_test = r2_score(y_test, y_pred_test2)

    print(f'RMSE Train: {rmse_train}')
    print(f"r2 Train: {r2_train}")

    print(f'RMSE Test: {rmse_test}')
    print(f"r2 Test: {r2_test}")
    
    return rmse_train,r2_train,rmse_test,r2_test

# %%
df_baseline = outage_focus_df.drop(columns = ['TOTAL.SALES','TOTAL.PRICE','UTIL.REALGSP','UTIL.CONTRI','OUTAGE.START'], axis=1)

# %%
X = df_baseline.drop(['IMPACT_SCORE'],axis=1)
y = df_baseline['IMPACT_SCORE'] 
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=23)

# %%
preproc = ColumnTransformer(
    transformers=[
        ('one-hot', OneHotEncoder(handle_unknown='ignore'), ['U.S._STATE','NERC.REGION','CAUSE.CATEGORY', 'CLIMATE.REGION'])],
    #('selector','passthrough',f)],
    remainder='passthrough',
    force_int_remainder_cols=False,
    verbose_feature_names_out=False
)
pl_random_forest = Pipeline([
    ('prep',preproc),
    ('random_forest', RandomForestRegressor(random_state=42))
])

pl_random_forest.fit(X_train, y_train)
b=results(pl_random_forest,X_train, X_test, y_train, y_test)
# Out:
# RMSE Train: 0.580762509992068
# r2 Train: 0.7152538918211958
# RMSE Test: 0.8921428877482582
# r2 Test: 0.3040027641411822

# %% [markdown]
# ## Step 7: Final Model

# %%
outage_focus_df['HOUR'] = outage_focus_df['OUTAGE.START'].dt.hour
outage_focus_df['DAY'] = outage_focus_df['OUTAGE.START'].dt.day
outage_focus_df = outage_focus_df.drop("OUTAGE.START",axis=1)



outage_focus_df["HOUR_SIN"] = np.sin(2 * np.pi * outage_focus_df["HOUR"] / 24)
outage_focus_df["HOUR_COS"] = np.cos(2 * np.pi * outage_focus_df["HOUR"] / 24)


outage_focus_df["MONTH_SIN"] = np.sin(2 * np.pi * outage_focus_df["MONTH"] / 12)
outage_focus_df["MONTH_COS"] = np.cos(2 * np.pi * outage_focus_df["MONTH"] / 12)

outage_focus_df["DAY_SIN"] = np.sin(2 * np.pi * outage_focus_df["DAY"] / 31)
outage_focus_df["DAY_COS"] = np.cos(2 * np.pi * outage_focus_df["DAY"] / 31)
outage_focus_df = outage_focus_df.drop(['HOUR','DAY','MONTH'],axis=1)

# %%
outage_focus_df['CUSTOMERS.DENSITY'] = outage_focus_df['TOTAL.CUSTOMERS'] / outage_focus_df['POPULATION']
outage_focus_df
# Out:
#         U.S._STATE NERC.REGION      CAUSE.CATEGORY  ANOMALY.LEVEL  \
# 1        Minnesota         MRO      severe weather           -0.3
# 2        Minnesota         MRO  intentional attack           -0.1
# 3        Minnesota         MRO      severe weather           -1.5
# 4        Minnesota         MRO      severe weather           -0.1
# 5        Minnesota         MRO      severe weather            1.2
# ...            ...         ...                 ...            ...
# 1527         Idaho        WECC  intentional attack            1.6
# 1528         Idaho        WECC  intentional attack            1.6
# 1530  North Dakota         MRO       public appeal           -0.9
# 1532  South Dakota         RFC           islanding            0.5
# 1533  South Dakota         MRO           islanding            0.5
#
#           CLIMATE.REGION  TOTAL.CUSTOMERS  TOTAL.PRICE  TOTAL.SALES  \
# 1     East North Central        2595696.0         9.28    6562520.0
# 2     East North Central        2640737.0         9.28    5284231.0
# 3     East North Central        2586905.0         8.15    5222116.0
# 4     East North Central        2606813.0         9.19    5787064.0
# 5     East North Central        2673531.0        10.43    5970339.0
# ...                  ...              ...          ...          ...
# 1527           Northwest         849763.0         8.05    1657605.0
# 1528           Northwest         849763.0         8.05    1657605.0
# 1530  West North Central         394394.0         7.56    1313678.0
# 1532  West North Central         436229.0         7.67     924051.0
# 1533  West North Central         436229.0         7.67     924051.0
#
#       TOTAL.REALGSP  UTIL.REALGSP  UTIL.CONTRI  POPULATION  POPDEN_URBAN  \
# 1          274182.0        4802.0     1.751391   5348119.0        2279.0
# 2          291955.0        5226.0     1.790002   5457125.0        2279.0
# 3          267895.0        4571.0     1.706266   5310903.0        2279.0
# 4          277627.0        5364.0     1.932089   5380443.0        2279.0
# 5          292023.0        4873.0     1.668704   5489594.0        2279.0
# ...             ...           ...          ...         ...           ...
# 1527        60911.0         960.0     1.576070   1680026.0        2216.8
# 1528        60911.0         960.0     1.576070   1680026.0        2216.8
# 1530        39067.0         934.0     2.390765    685326.0        2192.2
# 1532        36504.0         606.0     1.660092    807067.0        2038.3
# 1533        36504.0         606.0     1.660092    807067.0        2038.3
#
#         YEAR  IMPACT_SCORE  HOUR_SIN      HOUR_COS     MONTH_SIN  \
# 1     2011.0     -0.113518 -0.965926 -2.588190e-01 -5.000000e-01
# 2     2014.0     -0.638695 -1.000000 -1.836970e-16  5.000000e-01
# 3     2010.0     -0.120676 -0.866025  5.000000e-01 -8.660254e-01
# 4     2012.0     -0.179503  0.866025  5.000000e-01  1.224647e-16
# 5     2015.0      0.243088  0.500000  8.660254e-01 -5.000000e-01
# ...      ...           ...       ...           ...           ...
# 1527  2016.0     -0.569258  0.000000  1.000000e+00  1.000000e+00
# 1528  2016.0     -0.522110 -0.258819 -9.659258e-01  1.000000e+00
# 1530  2011.0     -0.494073  0.866025 -5.000000e-01 -2.449294e-16
# 1532  2009.0     -0.655477 -0.500000  8.660254e-01 -8.660254e-01
# 1533  2009.0     -0.633210  0.258819 -9.659258e-01 -8.660254e-01
#
#          MONTH_COS   DAY_SIN   DAY_COS  CUSTOMERS.DENSITY
# 1    -8.660254e-01  0.201299  0.979530           0.485347
# 2    -8.660254e-01  0.790776 -0.612106           0.483906
# 3     5.000000e-01 -0.848644  0.528964           0.487093
# 4    -1.000000e+00 -0.651372 -0.758758           0.484498
# 5    -8.660254e-01 -0.485302 -0.874347           0.487018
# ...            ...       ...       ...                ...
# 1527  6.123234e-17  0.998717 -0.050649           0.505803
# 1528  6.123234e-17  0.201299  0.979530           0.505803
# 1530  1.000000e+00  0.937752  0.347305           0.575484
# 1532 -5.000000e-01 -0.394356  0.918958           0.540512
# 1533 -5.000000e-01 -0.394356  0.918958           0.540512
#
# [1507 rows x 22 columns]

# %%
hyperparameters = {
    'random_forest__n_estimators': [100,102,105,150,200], # why? because more trees means more diversity(in usage of features and predictions) so could improve predictions
    'random_forest__max_depth': [10,11,12, 13, 14,15, 20, None] # because of over fitting and best depth for predictions
# note that i tried other hyperparameters but did not give me good results so just left them as default
}

# %%
X = outage_focus_df.drop(['IMPACT_SCORE'],axis=1)
y = outage_focus_df['IMPACT_SCORE']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=23)

# %%
# Takes a few seconds to run – how many trees are being trained?
grids = GridSearchCV(
    pl_random_forest,
    n_jobs=-1, # Use multiple processors to parallelize
    param_grid=hyperparameters,
    return_train_score=True
)
grids.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('prep',
#                                         ColumnTransformer(force_int_remainder_cols=False,
#                                                           remainder='passthrough',
#                                                           transformers=[('one-hot',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['U.S._STATE',
#                                                                           'NERC.REGION',
#                                                                           'CAUSE.CATEGORY',
#                                                                           'CLIMATE.REGION'])],
#                                                           verbose_feature_names_out=False)),
#                                        ('random_forest',
#                                         RandomForestRegressor(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'random_forest__max_depth': [10, 11, 12, 13, 14, 15,
#                                                       20, None],
#                          'random_forest__n_estimators': [100, 102, 105, 150,
#                                                          200]},
#              return_train_score=True)

# %%
grids.best_params_
# Out:
# {'random_forest__max_depth': 10, 'random_forest__n_estimators': 102}

# %%
s=results(grids,X_train, X_test, y_train, y_test)
# Out:
# RMSE Train: 0.5160649382563459
# r2 Train: 0.7751621842287234
# RMSE Test: 0.8069550707914643
# r2 Test: 0.4305738735545015

# %% [markdown]
# ## Step 8: Fairness Analysis

# %%
y_pred = grids.predict(X_test)
cutoff =X['POPULATION'].quantile(0.75)
results = X_test.copy()
results['prediction'] = y_pred
results['actual'] = y_test
results['is_highly_populated'] = (results['POPULATION'] > cutoff).replace({True: 'yes', False: 'no'})
results
# Out:
#           U.S._STATE NERC.REGION      CAUSE.CATEGORY  ANOMALY.LEVEL  \
# 1023       Louisiana        SERC   equipment failure           -0.2
# 89          Michigan         RFC      severe weather           -0.4
# 860         Missouri         SPP      severe weather           -0.4
# 554         Maryland         RFC      severe weather            0.3
# 26         Tennessee        SERC   equipment failure            0.5
# ...              ...         ...                 ...            ...
# 529         Maryland         RFC  intentional attack           -1.0
# 186            Texas         TRE       public appeal           -0.3
# 1422        Oklahoma         SPP      severe weather            2.2
# 810   South Carolina        SERC      severe weather           -0.5
# 475       Washington        WECC  intentional attack           -0.4
#
#           CLIMATE.REGION  TOTAL.CUSTOMERS  TOTAL.PRICE  TOTAL.SALES  \
# 1023               South        2311899.0         7.92    6406309.0
# 89    East North Central        4829741.0         8.76   10002112.0
# 860              Central        3072941.0         8.56    6132823.0
# 554            Northeast        2468101.0        11.31    4452722.0
# 26               Central        3153916.0         8.59    8950358.0
# ...                  ...              ...          ...          ...
# 529            Northeast        2461923.0        12.34    5155310.0
# 186                South       11084145.0         9.34   38540463.0
# 1422               South        2020012.0         7.25    4231978.0
# 810            Southeast        2511089.0         9.68    6513433.0
# 475            Northwest        3236484.0         6.94    7565294.0
#
#       TOTAL.REALGSP  UTIL.REALGSP  UTIL.CONTRI  POPULATION  POPDEN_URBAN  \
# 1023       205576.0        3907.0     1.900514   4627491.0        1685.8
# 89         420411.0        8589.0     2.043001  10001284.0        2034.1
# 860        249820.0        4845.0     1.939396   6010587.0        2053.5
# 554        317123.0        6643.0     2.094771   5890740.0        2511.4
# 26         247321.0        1598.0     0.646124   6306019.0        1450.3
# ...             ...           ...          ...         ...           ...
# 529        315930.0        6549.0     2.072928   5844171.0        2511.4
# 186       1246833.0       28045.0     2.249299  25654464.0        2435.3
# 1422       181045.0        4198.0     2.318761   3911338.0        1901.7
# 810        173785.0        4318.0     2.484679   4829160.0        1288.1
# 475        369797.0        3605.0     0.974859   6897292.0        2380.0
#
#         YEAR  HOUR_SIN      HOUR_COS  MONTH_SIN  MONTH_COS   DAY_SIN  \
# 1023  2013.0 -0.965926 -2.588190e-01   0.500000  -0.866025 -0.790776
# 89    2007.0 -0.965926  2.588190e-01  -0.500000  -0.866025  0.848644
# 860   2011.0 -0.965926 -2.588190e-01   0.500000  -0.866025 -0.968077
# 554   2012.0 -0.965926 -2.588190e-01  -0.866025   0.500000 -0.394356
# 26    2009.0  0.965926  2.588190e-01  -0.500000  -0.866025 -0.724793
# ...      ...       ...           ...        ...        ...       ...
# 529   2011.0 -0.500000 -8.660254e-01   0.866025   0.500000  0.571268
# 186   2011.0  0.258819 -9.659258e-01  -0.500000  -0.866025  0.299363
# 1422  2015.0  1.000000  6.123234e-17  -0.500000   0.866025 -0.571268
# 810   2014.0  0.258819 -9.659258e-01   0.866025   0.500000  0.651372
# 475   2012.0 -0.866025  5.000000e-01   0.866025  -0.500000 -0.897805
#
#        DAY_COS  CUSTOMERS.DENSITY  prediction    actual is_highly_populated
# 1023 -0.612106           0.499601   -0.448359 -0.589160                  no
# 89    0.528964           0.482912    0.107270  0.033946                  no
# 860  -0.250653           0.511255   -0.080322  0.888024                  no
# 554   0.918958           0.418980    0.319136  0.246055                  no
# 26    0.688967           0.500144   -0.307226 -0.287312                  no
# ...        ...                ...         ...       ...                 ...
# 529   0.820763           0.421261   -0.570237 -0.564433                  no
# 186  -0.954139           0.432055   -0.473854 -0.573899                 yes
# 1422  0.820763           0.516450    0.354804 -0.155746                  no
# 810  -0.758758           0.519985    0.551344  0.162898                  no
# 475  -0.440394           0.469240   -0.583597 -0.269342                  no
#
# [302 rows x 24 columns]

# %%
compute_rmse = lambda x: root_mean_squared_error(x['actual'], x['prediction'])

# %%
(
    results
    .groupby('is_highly_populated')
    [['actual', 'prediction']]
    .apply(compute_rmse)
    .rename('rmse').diff()
)
# Out:
# is_highly_populated
# no          NaN
# yes    0.029629
# Name: rmse, dtype: float64

# %% [markdown]
# ### Is this difference in RMSE significant?
#
# Let's run a **permutation test** to see if the difference in accuracy is significant.
# - **Null Hypothesis**: Our model is fair. The RMSE is the same for both highly populated and not highly populated states, and any differences is due to chance.
# - **Alternative Hypothesis**: Our model is unfair. The RMSE is higher for highly populated states.
# - Test statistic: Difference in accuracy (young minus old).
# - Significance level: 0.01.

# %%
obs = (
    results
    .groupby('is_highly_populated')
    [['actual', 'prediction']]
    .apply(compute_rmse)
    .rename('rmse').diff().iloc[-1]
)
obs
# Out:
# 0.02962867617075171

# %%
np.random.seed(21)
diff_in_acc = []
for _ in range(1000):
    s = (
        results[['is_highly_populated', 'prediction', 'actual']]
        .assign(is_highly_populated=np.random.permutation(results['is_highly_populated']))
        .groupby('is_highly_populated')
        [['actual', 'prediction']]
        .apply(compute_rmse)
        .diff()
        .iloc[-1]
    )
    
    diff_in_acc.append(np.abs(s))

# %%
p_value = (diff_in_acc >= obs).mean()
p_value
# Out:
# 0.971

# %%
fig = px.histogram(pd.DataFrame({'diff_means':diff_in_acc}),histnorm='probability',
                   title='Empirical Distribution of the difference in RMSE')
fig.add_vline(x=obs, line_color='red', line_width=2, opacity=1)
fig.add_annotation(text=f'<span style="color:red">Observed TVD = {round(obs, 2)}</span>',
                   x=4.2 * obs, showarrow=False, y=0.14)
fig.update_layout(showlegend=False)
fig.update_layout(
    xaxis_title="Generated Difference in RMSE"  
)
fig.update_layout(
    width=800,  
    height=600   
)
